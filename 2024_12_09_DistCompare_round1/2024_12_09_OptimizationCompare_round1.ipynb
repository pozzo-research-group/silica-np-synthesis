# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests

# ----------- Science Jubilee -------------
from science_jubilee import Machine as Jub
from science_jubilee.tools import HTTPSyringe as syringe
from science_jubilee.tools import Pipette
from science_jubilee.utils import Handlers
import time
import numpy as np
import pandas as pd
import logging
import sys
sys.path.append('..')
import stober_synthesis_utils as stober

# %%
FORMAT = '%(asctime)s:%(levelname)s:%(name)s:%(message)s'
logging.basicConfig(filename = '2024_10_10_random3try2.log', level = logging.INFO, format = FORMAT)
logger = logging.getLogger(__name__)

# %%
jubilee = Jub.Machine(address='192.168.1.2', simulated = False, crash_detection = False)

# %% [raw]
# jubilee.home_all()
# logger.info('Homed Jubilee')

# %%
deck = jubilee.load_deck('lab_automation_deck_AFL_bolton.json')

# %%
sample_table_rmse = pd.read_csv('Sample_table_2024_12_09_CompareOptRound1_rmsedist.csv')
sample_table_apdist = pd.read_csv('Sample_table_2024_12_09_CompareOptRound1_apdist.csv')

# %%
stober.count_stock_vials(sample_table_rmse, 15000)
# Out:
# {'teos_count': 1, 'ammonia_count': 1, 'water_count': 1, 'ethanol_count': 2}

# %%
sample_table_apdist['ethanol_volume'].sum()/10000
# Out:
# 2.790809116018936

# %% [markdown]
# ## Load Tools

# %%
syringe_10 = syringe.HTTPSyringe.from_config(1, "../../science-jubilee/src/science_jubilee/tools/configs/10cc_syringe.json")
syringe_1_1 = syringe.HTTPSyringe.from_config(2, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_1_syringe.json")
syringe_1_2 = syringe.HTTPSyringe.from_config(3, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_2_syringe.json")
syringe_1_3 = syringe.HTTPSyringe.from_config(4, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_3_syringe.json")

# %%
jubilee.load_tool(syringe_10)
jubilee.load_tool(syringe_1_1)
jubilee.load_tool(syringe_1_2)
jubilee.load_tool(syringe_1_3)

# %%
mix_syringe = syringe_10
water_syringe = syringe_1_1
ammonia_syringe = syringe_1_2
teos_syringe = syringe_1_3

# %% [markdown]
# ## Load water syringe with water

# %%
water_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
water_syringe.set_pulsewidth(water_syringe.empty_position-1, s = 2000)

# %%
water_syringe.set_pulsewidth(water_syringe.full_position+1, s = 10)

# %%
water_syringe.set_pulsewidth(water_syringe.full_position+150, s = 500)

# %%
water_syringe.load_syringe(750, water_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 750 uL

# %% [markdown]
# ## Load ammonia syringe

# %%
ammonia_syringe.set_pulsewidth(1420, s = 10)

# %%
ammonia_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.empty_position-1, s = 2000)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+1, s = 10)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+350, s = 500)

# %%
ammonia_syringe.load_syringe(370, ammonia_syringe.full_position+350)
# Out:
# Loaded syringe, remaining volume 370 uL

# %% [markdown]
# ## Load TEOS syringe

# %%
teos_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
teos_syringe.set_pulsewidth(teos_syringe.empty_position-1, s = 2000)

# %%
teos_syringe.set_pulsewidth(teos_syringe.full_position+1, s = 100)

# %%
teos_syringe.set_pulsewidth(teos_syringe.full_position+200, s = 200)

# %%
teos_syringe.load_syringe(690, teos_syringe.full_position+200)
# Out:
# Loaded syringe, remaining volume 690 uL

# %% [markdown]
# ## load ethanol syringe

# %%
#jubilee.park_tool()

# %%
mix_syringe.load_syringe(0, mix_syringe.empty_position-1)
# Out:
# Loaded syringe, remaining volume 0 uL

# %%
mix_syringe.set_pulsewidth(mix_syringe.empty_position-1, s = 2000)

# %%
mix_syringe.set_pulsewidth(mix_syringe.full_position+1, s = 10)

# %%
mix_syringe.empty_position
# Out:
# 1830

# %%
mix_syringe.set_pulsewidth(mix_syringe.full_position+150, s = 500)

# %%
mix_syringe.load_syringe(7200, mix_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 7200 uL

# %% [markdown]
# ## Load labware

# %%
samples_apdist = jubilee.load_labware('septavialrev1_44_holder_2000ul.json', 2)
samples_apdist.manual_offset([(18.6,  173.3), (131.9, 173.9), (132.5, 104.0)])
# Out:
# -0.006939552938430424
# New manual offset applied to septavialrev1_44_holder_2000ul

# %%
samples_rmse = jubilee.load_labware('septavialrev1_44_holder_2000ul.json', 3)
samples_rmse.manual_offset([(160.1, 174.5), (271.3, 174.8), (271.4, 105.3)])
# Out:
# -0.0020683415546615585
# New manual offset applied to septavialrev1_44_holder_2000ul

# %%
stocks_main = jubilee.load_labware('20mlscintillation_12_wellplate_18000ul.json', 4)
stocks_main.manual_offset([(32.5, 263.3), (117.5, 263.3),  (117.5, 207.3)])
# Out:
# -0.0
# New manual offset applied to 20mlscintillation_12_wellplate_18000ul

# %%
stocks_extra = jubilee.load_labware('20mlscintillation_12_wellplate_18000ul.json', 5)
stocks_extra.manual_offset([(173.4, 264.3), (257.4, 265.3), (258.4, 208.3)])
# Out:
# -0.014723129807859146
# New manual offset applied to 20mlscintillation_12_wellplate_18000ul

# %%
trash = jubilee.load_labware('agilent_1_reservoir_290ml.json', 1)

# %%
teos_stocks = [stocks_main[0]]
ammonia_stocks = [stocks_main[1]]
water_stocks = [stocks_main[2]]
ethanol_stocks_apdist = [stocks_main[3], stocks_main[4], stocks_main[5], stocks_main[6], stocks_main[7], stocks_main[8]]
rinse_stocks_apdist = [stocks_main[9], stocks_main[10], stocks_main[11]]

# %%
ethanol_stocks_rmse = [stocks_extra[0], stocks_extra[1], stocks_extra[2], stocks_extra[3], stocks_extra[4], stocks_extra[5]]
rinse_stocks_rmse = [stocks_extra[6], stocks_extra[7], stocks_extra[8]]

# %% [markdown]
# ## Check sample alignment

# %%
jubilee.pickup_tool(mix_syringe)
for well in stocks_extra:
    jubilee.move_to(x = well.x, y = well.y)
    jubilee.move_to(z = well.top_+7)
    ans = input(f'Is the tip centered over well?')
    if ans == 'y':
        continue
    else:
        continue
# Out:
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?
# Is the tip centered over well?

# %%
jubilee.park_tool()

# %%
jubilee.pickup_tool(teos_syringe)
for i, row in sample_table_apdist.iterrows():
    loc = samples_apdist[row['well']]
    jubilee.move_to(x = loc.x, y = loc.y)
    jubilee.move_to(z = loc.top_+7)
    curr_well = row['well']
    ans = input(f'Is the tip centered over sample {curr_well}?')
    if ans == 'y':
        continue
    else:
        continue
# Out:
# Is the tip centered over sample A1?
# Is the tip centered over sample A2?
# Is the tip centered over sample A3?
# Is the tip centered over sample A4?
# Is the tip centered over sample A5?
# Is the tip centered over sample A6?
# Is the tip centered over sample A7?
# Is the tip centered over sample A8?
# Is the tip centered over sample B1?
# Is the tip centered over sample B3?
# Is the tip centered over sample B4?
# Is the tip centered over sample B5?
# Is the tip centered over sample B6?
# Is the tip centered over sample B8?
# Is the tip centered over sample C1?
# Is the tip centered over sample C2?
# Is the tip centered over sample C3?
# Is the tip centered over sample C4?
# Is the tip centered over sample C5?
# Is the tip centered over sample C6?

# %%
loc.x
# Out:
# 130.29143531738507

# %%
jubilee.park_tool()

# %% [markdown]
# # Experiment

# %%
location_lookup_apdist = {row['uuid']:samples_apdist[row['well']] for i, row in sample_table_apdist.iterrows()}
location_lookup_rmse = {row['uuid']:samples_rmse[row['well']] for i, row in sample_table_rmse.iterrows()}

# %%
sample_table_apdist
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  2a2489cf-cb30-4795-bad7-d0431dc3d6e9    17.000000
# 1            1  547378d7-9885-4f7b-bb76-1cad9fe9ecbe    17.000000
# 2            2  e9e81d8d-52c7-4674-a252-73dc22860a76    84.038457
# 3            3  b75de8df-6d84-4469-8486-f45cfefc50a9    17.000000
# 4            4  a658f6a0-f3c1-4540-b4d3-27df0be4d763   178.838645
# 5            5  f94cbec2-df68-4ff8-ba33-c350c8f1ceee    17.000000
# 6            6  848d6459-a4c0-4f9b-80ee-df78cc9ba1c2   224.687947
# 7            7  8989ee73-e02f-4415-b531-79a90e78785c    17.000000
# 8            8  df88eebb-78ce-401c-8eb7-96e997f57fee   115.489179
# 9            9  dd59c063-7661-411c-8790-7101a3c733a9    17.000000
# 10          10  6cb580fd-3a5f-4704-9ba1-7951139d9565   156.371932
# 11          11  dd0c2d6b-3300-485f-a910-3edbad96b555    17.000000
# 12          12  1d5c5e7c-cc2c-4253-be39-130d15bd8248    94.573809
# 13          13  34039d94-fd7d-4e25-b03b-5050d7222182    17.000000
# 14          14  c0b02769-f867-477e-b835-f86ce2de7ccf   197.883831
# 15          15  3cab9df6-14ff-4c7a-8523-d62d69ab932b   119.694667
# 16          16  1d4392b1-e0f5-49ac-ac0a-4eef24e0a85e    17.000000
# 17          17  5bf68a4a-dcb1-4433-8158-c9e6442b158f   184.617615
# 18          18  3d4e977d-003a-41cb-99ab-a74c10898d91    17.000000
# 19          19  97c4c096-82d1-42b4-8a3a-3b5bb9d3dd9c    97.011226
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0         8.500000    186.777369     1487.722632                  2.232143
# 1        29.839564    162.198122     1490.962314                  2.232143
# 2       101.360049     54.186473     1460.415022                  0.451536
# 3        90.520301     71.892193     1520.587507                  2.232143
# 4       111.703518    222.602391     1186.855446                  0.212182
# 5        79.965278      8.500000     1594.534723                  2.232143
# 6       126.462040    157.065079     1191.784934                  0.168885
# 7       102.725917      8.500000     1571.774083                  2.232143
# 8       159.580974     11.105582     1413.824265                  0.328571
# 9        67.924604    114.580217     1500.495179                  2.232143
# 10       18.368069    124.744672     1400.515327                  0.242668
# 11       37.052040    255.000010     1390.947950                  2.232143
# 12      178.869056    168.294920     1258.262215                  0.401236
# 13        8.500000    255.000010     1419.499990                  2.232143
# 14      153.327561     50.724428     1298.064180                  0.191761
# 15       70.704573    228.604726     1280.996034                  0.317027
# 16      186.999999    255.000010     1240.999991                  2.232143
# 17       82.020461    135.031771     1298.330153                  0.205541
# 18      133.920001      8.500000     1540.579999                  2.232143
# 19       95.475678    146.573880     1360.939216                  0.391155
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0           2.691584              0.003306                 0.0
# 1           2.691584              0.003312                 0.0
# 2          13.305680              0.016433               932.0
# 3           2.691584              0.003342                 0.0
# 4          28.315249              0.033744              1339.0
# 5           2.691584              0.003377                 0.0
# 6          35.574499              0.042558              1413.0
# 7           2.691584              0.003371                 0.0
# 8          18.285225              0.022551              1141.0
# 9           2.691584              0.003326                 0.0
# 10         24.758129              0.030227              1287.0
# 11          2.691584              0.003264                 0.0
# 12         14.973727              0.018048              1018.0
# 13          2.691584              0.003272                 0.0
# 14         31.330644              0.038101              1374.0
# 15         18.951073              0.022773              1161.0
# 16          2.691584              0.003226                 0.0
# 17         29.230225              0.035349              1351.0
# 18          2.691584              0.003362                 0.0
# 19         15.359639              0.018691              1035.0
#
#     sample_dilute_vol well dilute_well
# 0              1700.0   A1          C7
# 1              1700.0   A2          C8
# 2               768.0   A3          D1
# 3              1700.0   A4          D2
# 4               361.0   A5          D3
# 5              1700.0   A6          D4
# 6               287.0   A7          D5
# 7              1700.0   A8          D6
# 8               559.0   B1          D7
# 9              1700.0   B3          D8
# 10              413.0   B4          E1
# 11             1700.0   B5          E3
# 12              682.0   B6          E4
# 13             1700.0   B8          E5
# 14              326.0   C1          E6
# 15              539.0   C2          E8
# 16             1700.0   C3          F1
# 17              349.0   C4          F2
# 18             1700.0   C5          F3
# 19              665.0   C6          F4

# %%
dilution_table_apdist = sample_table_apdist.copy()
dilution_table_rmse = sample_table_rmse.copy()

# %%
dilution_table_apdist['well'] = dilution_table_apdist['dilute_well']
dilution_table_rmse['well'] = dilution_table_rmse['dilute_well']

# %%
dilution_table_rmse
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  1f1eda63-fd7c-4d4f-84bb-1ddd0c2a99dd    17.000000
# 1            1  4e75e479-49bf-4a65-8ae3-3f085a379b2e   125.223370
# 2            2  d4080418-1355-4edb-a071-e2e1d257a27a    17.000000
# 3            3  c9d10e89-9f9c-447a-bcbb-cb4f3f4dd2ce   104.881934
# 4            4  5d85aab2-c809-4d5a-b304-4da90d7fd8eb    17.000000
# 5            5  883b00e1-0c5a-4073-84f4-2abf1f29311a    17.000000
# 6            6  23555ebb-5cd3-480b-91ba-8151eb1c2adf    17.000000
# 7            7  b53fb2da-5b56-445a-9f70-51f8ddeb15b8   124.725407
# 8            8  631d7d59-57a3-4a2d-9217-d19dd1ffa0cc    90.538476
# 9            9  1f4da550-f24a-4b03-a0e9-4b171e4f9340   255.000010
# 10          10  aa252059-c33e-4275-86d0-281dc497d0f3    82.145043
# 11          11  713f869c-0dc3-49b2-85e3-92753b4472d0    17.000000
# 12          12  d1822b83-bd6b-439e-954d-97148ca11681   146.358735
# 13          13  59e392bb-0da9-47a5-8fa3-d673842514e1    17.000000
# 14          14  07e8b692-f005-45cd-b11f-20f7d7799fe2    17.000000
# 15          15  d0007687-faec-4deb-b4ea-a9e12ef0c229    17.000000
# 16          16  8ba0c6b7-3832-481e-bb23-e1c1513e39da   156.438771
# 17          17  3d7aafbc-c0a5-497f-aef7-762b42bea8b2    17.000000
# 18          18  823420a0-9489-4474-98b7-8002db0ccdfa    45.910634
# 19          19  0ec1c475-cfcb-4825-99d1-8aa99d749a94    17.000000
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0        39.032291    255.000010     1388.967699                  2.232143
# 1       103.300117    123.509941     1347.966573                  0.303030
# 2        38.368599    220.977674     1423.653726                  2.232143
# 3       156.893239    132.681052     1305.543774                  0.361801
# 4        68.094050    176.708809     1438.197142                  2.232143
# 5       104.730696      8.500000     1569.769305                  2.232143
# 6       108.679742     93.947571     1480.372688                  2.232143
# 7       153.353197     45.015551     1376.905845                  0.304240
# 8        13.572815    119.604776     1476.283933                  0.419119
# 9         8.500000    255.000010     1181.499980                  0.148810
# 10      157.028917     99.040096     1361.785943                  0.461944
# 11       85.094097    113.013890     1484.892013                  2.232143
# 12      145.470254    147.629045     1260.541966                  0.259270
# 13        8.500000    208.180911     1466.319089                  2.232143
# 14      134.401271      8.500000     1540.098730                  2.232143
# 15        8.500000    255.000010     1419.499990                  2.232143
# 16       74.285032     75.595474     1393.680723                  0.242564
# 17        8.500000    159.909378     1514.590623                  2.232143
# 18      148.858152    171.079487     1334.151727                  0.826528
# 19       94.794014    164.466790     1423.739197                  2.232143
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0           2.691584              0.003264                 0.0
# 1          19.826425              0.024125              1185.0
# 2           2.691584              0.003281                 0.0
# 3          16.605796              0.020135              1085.0
# 4           2.691584              0.003295                 0.0
# 5           2.691584              0.003370                 0.0
# 6           2.691584              0.003326                 0.0
# 7          19.747583              0.024218              1183.0
# 8          14.334818              0.017642               987.0
# 9          40.373762              0.047903              1447.0
# 10         13.005899              0.015886               915.0
# 11          2.691584              0.003322                 0.0
# 12         23.172755              0.027941              1259.0
# 13          2.691584              0.003295                 0.0
# 14          2.691584              0.003362                 0.0
# 15          2.691584              0.003272                 0.0
# 16         24.768711              0.030328              1288.0
# 17          2.691584              0.003319                 0.0
# 18          7.268961              0.008822               295.0
# 19          2.691584              0.003294                 0.0
#
#     sample_dilute_vol well dilute_well
# 0              1700.0   C7          C7
# 1               515.0   C8          C8
# 2              1700.0   D1          D1
# 3               615.0   D2          D2
# 4              1700.0   D3          D3
# 5              1700.0   D4          D4
# 6              1700.0   D5          D5
# 7               517.0   D6          D6
# 8               713.0   D7          D7
# 9               253.0   D8          D8
# 10              785.0   E1          E1
# 11             1700.0   E3          E3
# 12              441.0   E4          E4
# 13             1700.0   E5          E5
# 14             1700.0   E6          E6
# 15             1700.0   E8          E8
# 16              412.0   F1          F1
# 17             1700.0   F2          F2
# 18             1405.0   F3          F3
# 19             1700.0   F4          F4

# %%
location_lookup_dilute_apdist = {}

for i, row in dilution_table_apdist.iterrows():
    uuid_val = row['uuid']
    well = row['well']
    if well is not np.nan:
        well_loc = samples_apdist[well]
    else:
        well_loc = None

    location_lookup_dilute_apdist[uuid_val] = well_loc

# %%
location_lookup_dilute_rmse = {}

for i, row in dilution_table_rmse.iterrows():
    uuid_val = row['uuid']
    well = row['well']
    if well is not np.nan:
        well_loc = samples_rmse[well]
    else:
        well_loc = None

    location_lookup_dilute_rmse[uuid_val] = well_loc

# %% [markdown]
# ## add ethanol

# %%
stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, sample_table_apdist, location_lookup_apdist, 'ethanol_volume', ethanol_stocks_apdist, stocks_usable_volume=15000, dwell_time = 10)
stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, sample_table_rmse, location_lookup_rmse, 'ethanol_volume', ethanol_stocks_rmse, stocks_usable_volume=15000, dwell_time = 10)

# %%
#dispense remaining volume from etOH mix syringe
jubilee.pickup_tool(mix_syringe)
mix_syringe.dispense(mix_syringe.remaining_volume-1, trash[0])
logger.info('Emptied ethanol syringe into trash')
jubilee.park_tool()

# %%
mix_syringe.set_pulsewidth(mix_syringe.empty_position-1)

# %% [markdown]
# ## Dispense water

# %%
stober.add_reactants_batch(jubilee, water_syringe, mix_syringe, sample_table_apdist, location_lookup_apdist, 'water_volume', water_stocks, dwell_time = 7)

# %%
stober.add_reactants_batch(jubilee, water_syringe, mix_syringe, sample_table_rmse, location_lookup_rmse, 'water_volume', water_stocks, dwell_time = 7)

# %% [markdown]
# ## dispense Ammonia

# %%
stober.add_reactants_batch(jubilee, ammonia_syringe, mix_syringe, sample_table_apdist, location_lookup_apdist, 'ammonia_volume', ammonia_stocks)

# %%
stober.add_reactants_batch(jubilee, ammonia_syringe, mix_syringe, sample_table_rmse, location_lookup_rmse, 'ammonia_volume', ammonia_stocks)

# %% [markdown]
# ## mix precursors

# %%
stober.first_mix(jubilee, mix_syringe, 2000, location_lookup_apdist, rinse_stocks_apdist, 5)

# %%
stober.first_mix(jubilee, mix_syringe, 2000, location_lookup_rmse, rinse_stocks_rmse, 5)

# %% [markdown]
# ## Add TEOS and mix

# %%
teos_start_time
# Out:
# 1733804110.2581208

# %%
teos_start_time = time.time()

# %%
stober.add_reactants_batch(jubilee, teos_syringe, mix_syringe, sample_table_apdist, location_lookup_apdist, 'teos_volume', teos_stocks, mix_after=(2000, 5, rinse_stocks_apdist))

# %%
stober.add_reactants_batch(jubilee, teos_syringe, mix_syringe, sample_table_rmse, location_lookup_rmse, 'teos_volume', teos_stocks, mix_after=(2000, 5, rinse_stocks_rmse))

# %%
mix_syringe.remaining_volume
# Out:
# 8113.0

# %% [markdown]
# ### Dilution

# %%
##hrs5 = 60*60*5
#while (time.time() - teos_start_time) < hrs5:
    #time.sleep(60)

# dispese ethanol into dilution vials
#stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, dilution_table_apdist, location_lookup_dilute_apdist, 'ethanol_dilute_vol', ethanol_stocks_apdist[4:], stocks_usable_volume=15000, dwell_time = 10)

jubilee.pickup_tool(mix_syringe)
mix_syringe.dispense(mix_syringe.remaining_volume-1, trash[0])
logger.info('Emptied ethanol syringe into trash')
jubilee.park_tool()

jubilee.pickup_tool(mix[(18.6,  173.3), (131.9, 173.9), (132.5, 104.0)]
_syringe)
rinse_vol = 2000
for i, row in dilution_table_apdist.iterrows():
    if i == 0:
        continue
    if i == 1:
        continue
    uuid_val = row['uuid']
    sample_well = location_lookup_apdist[uuid_val]
    dilute_well = location_lookup_dilute_apdist[uuid_val]
    if dilute_well is None:
        continue
    else:
        vol = row['sample_dilute_vol']
        
        mix_syringe.aspirate(vol, sample_well.bottom(+5))
        time.sleep(10)
        mix_syringe.dispense(vol, dilute_well.bottom(+5))
        time.sleep(10)
        logger.info(f'Transferred {vol} uL from {sample_well} to {dilute_well}')
    
        for stock in rinse_stocks_apdist:
            mix_syringe.mix(rinse_vol, 5, stock.bottom(+10), t_hold = 3, s_aspirate = 2000, s_dispense = 500)
    
        logger.info(f'Washed mix syringe in wash solutions {rinse_stocks_apdist}')

# %%
i
# Out:
# 0

# %%
# dispese ethanol into dilution vials
stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, dilution_table_rmse, location_lookup_dilute_rmse, 'ethanol_dilute_vol', ethanol_stocks_rmse[4:], stocks_usable_volume=15000, dwell_time = 10)

jubilee.pickup_tool(mix_syringe)
mix_syringe.dispense(mix_syringe.remaining_volume-1, trash[0])
logger.info('Emptied ethanol syringe into trash')
jubilee.park_tool()

jubilee.pickup_tool(mix_syringe)
rinse_vol = 2000
for i, row in dilution_table_rmse.iterrows():
    uuid_val = row['uuid']
    sample_well = location_lookup_rmse[uuid_val]
    dilute_well = location_lookup_dilute_rmse[uuid_val]
    if dilute_well is None:
        continue
    else:
        vol = row['sample_dilute_vol']
        
        mix_syringe.aspirate(vol, sample_well.bottom(+5))
        time.sleep(10)
        mix_syringe.dispense(vol, dilute_well.bottom(+5))
        time.sleep(10)
        logger.info(f'Transferred {vol} uL from {sample_well} to {dilute_well}')
    
        for stock in rinse_stocks_rmse:
            mix_syringe.mix(rinse_vol, 5, stock.bottom(+10), t_hold = 3, s_aspirate = 2000, s_dispense = 500)
    
        logger.info(f'Washed mix syringe in wash solutions {rinse_stocks_rmse}')

# %%
jubilee.park_tool()

# %%
water_syringe.set_pulsewidth(water_syringe.empty_position-1)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.empty_position-1)

# %%
teos_syringe.set_pulsewidth(teos_syringe.empty_position-1)

# %%
sample_table_apdist
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  2a2489cf-cb30-4795-bad7-d0431dc3d6e9    17.000000
# 1            1  547378d7-9885-4f7b-bb76-1cad9fe9ecbe    17.000000
# 2            2  e9e81d8d-52c7-4674-a252-73dc22860a76    84.038457
# 3            3  b75de8df-6d84-4469-8486-f45cfefc50a9    17.000000
# 4            4  a658f6a0-f3c1-4540-b4d3-27df0be4d763   178.838645
# 5            5  f94cbec2-df68-4ff8-ba33-c350c8f1ceee    17.000000
# 6            6  848d6459-a4c0-4f9b-80ee-df78cc9ba1c2   224.687947
# 7            7  8989ee73-e02f-4415-b531-79a90e78785c    17.000000
# 8            8  df88eebb-78ce-401c-8eb7-96e997f57fee   115.489179
# 9            9  dd59c063-7661-411c-8790-7101a3c733a9    17.000000
# 10          10  6cb580fd-3a5f-4704-9ba1-7951139d9565   156.371932
# 11          11  dd0c2d6b-3300-485f-a910-3edbad96b555    17.000000
# 12          12  1d5c5e7c-cc2c-4253-be39-130d15bd8248    94.573809
# 13          13  34039d94-fd7d-4e25-b03b-5050d7222182    17.000000
# 14          14  c0b02769-f867-477e-b835-f86ce2de7ccf   197.883831
# 15          15  3cab9df6-14ff-4c7a-8523-d62d69ab932b   119.694667
# 16          16  1d4392b1-e0f5-49ac-ac0a-4eef24e0a85e    17.000000
# 17          17  5bf68a4a-dcb1-4433-8158-c9e6442b158f   184.617615
# 18          18  3d4e977d-003a-41cb-99ab-a74c10898d91    17.000000
# 19          19  97c4c096-82d1-42b4-8a3a-3b5bb9d3dd9c    97.011226
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0         8.500000    186.777369     1487.722632                  2.232143
# 1        29.839564    162.198122     1490.962314                  2.232143
# 2       101.360049     54.186473     1460.415022                  0.451536
# 3        90.520301     71.892193     1520.587507                  2.232143
# 4       111.703518    222.602391     1186.855446                  0.212182
# 5        79.965278      8.500000     1594.534723                  2.232143
# 6       126.462040    157.065079     1191.784934                  0.168885
# 7       102.725917      8.500000     1571.774083                  2.232143
# 8       159.580974     11.105582     1413.824265                  0.328571
# 9        67.924604    114.580217     1500.495179                  2.232143
# 10       18.368069    124.744672     1400.515327                  0.242668
# 11       37.052040    255.000010     1390.947950                  2.232143
# 12      178.869056    168.294920     1258.262215                  0.401236
# 13        8.500000    255.000010     1419.499990                  2.232143
# 14      153.327561     50.724428     1298.064180                  0.191761
# 15       70.704573    228.604726     1280.996034                  0.317027
# 16      186.999999    255.000010     1240.999991                  2.232143
# 17       82.020461    135.031771     1298.330153                  0.205541
# 18      133.920001      8.500000     1540.579999                  2.232143
# 19       95.475678    146.573880     1360.939216                  0.391155
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0           2.691584              0.003306                 0.0
# 1           2.691584              0.003312                 0.0
# 2          13.305680              0.016433               932.0
# 3           2.691584              0.003342                 0.0
# 4          28.315249              0.033744              1339.0
# 5           2.691584              0.003377                 0.0
# 6          35.574499              0.042558              1413.0
# 7           2.691584              0.003371                 0.0
# 8          18.285225              0.022551              1141.0
# 9           2.691584              0.003326                 0.0
# 10         24.758129              0.030227              1287.0
# 11          2.691584              0.003264                 0.0
# 12         14.973727              0.018048              1018.0
# 13          2.691584              0.003272                 0.0
# 14         31.330644              0.038101              1374.0
# 15         18.951073              0.022773              1161.0
# 16          2.691584              0.003226                 0.0
# 17         29.230225              0.035349              1351.0
# 18          2.691584              0.003362                 0.0
# 19         15.359639              0.018691              1035.0
#
#     sample_dilute_vol well dilute_well
# 0              1700.0   A1          C7
# 1              1700.0   A2          C8
# 2               768.0   A3          D1
# 3              1700.0   A4          D2
# 4               361.0   A5          D3
# 5              1700.0   A6          D4
# 6               287.0   A7          D5
# 7              1700.0   A8          D6
# 8               559.0   B1          D7
# 9              1700.0   B3          D8
# 10              413.0   B4          E1
# 11             1700.0   B5          E3
# 12              682.0   B6          E4
# 13             1700.0   B8          E5
# 14              326.0   C1          E6
# 15              539.0   C2          E8
# 16             1700.0   C3          F1
# 17              349.0   C4          F2
# 18             1700.0   C5          F3
# 19              665.0   C6          F4

# %%
sample_table_rmse
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  1f1eda63-fd7c-4d4f-84bb-1ddd0c2a99dd    17.000000
# 1            1  4e75e479-49bf-4a65-8ae3-3f085a379b2e   125.223370
# 2            2  d4080418-1355-4edb-a071-e2e1d257a27a    17.000000
# 3            3  c9d10e89-9f9c-447a-bcbb-cb4f3f4dd2ce   104.881934
# 4            4  5d85aab2-c809-4d5a-b304-4da90d7fd8eb    17.000000
# 5            5  883b00e1-0c5a-4073-84f4-2abf1f29311a    17.000000
# 6            6  23555ebb-5cd3-480b-91ba-8151eb1c2adf    17.000000
# 7            7  b53fb2da-5b56-445a-9f70-51f8ddeb15b8   124.725407
# 8            8  631d7d59-57a3-4a2d-9217-d19dd1ffa0cc    90.538476
# 9            9  1f4da550-f24a-4b03-a0e9-4b171e4f9340   255.000010
# 10          10  aa252059-c33e-4275-86d0-281dc497d0f3    82.145043
# 11          11  713f869c-0dc3-49b2-85e3-92753b4472d0    17.000000
# 12          12  d1822b83-bd6b-439e-954d-97148ca11681   146.358735
# 13          13  59e392bb-0da9-47a5-8fa3-d673842514e1    17.000000
# 14          14  07e8b692-f005-45cd-b11f-20f7d7799fe2    17.000000
# 15          15  d0007687-faec-4deb-b4ea-a9e12ef0c229    17.000000
# 16          16  8ba0c6b7-3832-481e-bb23-e1c1513e39da   156.438771
# 17          17  3d7aafbc-c0a5-497f-aef7-762b42bea8b2    17.000000
# 18          18  823420a0-9489-4474-98b7-8002db0ccdfa    45.910634
# 19          19  0ec1c475-cfcb-4825-99d1-8aa99d749a94    17.000000
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0        39.032291    255.000010     1388.967699                  2.232143
# 1       103.300117    123.509941     1347.966573                  0.303030
# 2        38.368599    220.977674     1423.653726                  2.232143
# 3       156.893239    132.681052     1305.543774                  0.361801
# 4        68.094050    176.708809     1438.197142                  2.232143
# 5       104.730696      8.500000     1569.769305                  2.232143
# 6       108.679742     93.947571     1480.372688                  2.232143
# 7       153.353197     45.015551     1376.905845                  0.304240
# 8        13.572815    119.604776     1476.283933                  0.419119
# 9         8.500000    255.000010     1181.499980                  0.148810
# 10      157.028917     99.040096     1361.785943                  0.461944
# 11       85.094097    113.013890     1484.892013                  2.232143
# 12      145.470254    147.629045     1260.541966                  0.259270
# 13        8.500000    208.180911     1466.319089                  2.232143
# 14      134.401271      8.500000     1540.098730                  2.232143
# 15        8.500000    255.000010     1419.499990                  2.232143
# 16       74.285032     75.595474     1393.680723                  0.242564
# 17        8.500000    159.909378     1514.590623                  2.232143
# 18      148.858152    171.079487     1334.151727                  0.826528
# 19       94.794014    164.466790     1423.739197                  2.232143
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0           2.691584              0.003264                 0.0
# 1          19.826425              0.024125              1185.0
# 2           2.691584              0.003281                 0.0
# 3          16.605796              0.020135              1085.0
# 4           2.691584              0.003295                 0.0
# 5           2.691584              0.003370                 0.0
# 6           2.691584              0.003326                 0.0
# 7          19.747583              0.024218              1183.0
# 8          14.334818              0.017642               987.0
# 9          40.373762              0.047903              1447.0
# 10         13.005899              0.015886               915.0
# 11          2.691584              0.003322                 0.0
# 12         23.172755              0.027941              1259.0
# 13          2.691584              0.003295                 0.0
# 14          2.691584              0.003362                 0.0
# 15          2.691584              0.003272                 0.0
# 16         24.768711              0.030328              1288.0
# 17          2.691584              0.003319                 0.0
# 18          7.268961              0.008822               295.0
# 19          2.691584              0.003294                 0.0
#
#     sample_dilute_vol well dilute_well
# 0              1700.0   A1          C7
# 1               515.0   A2          C8
# 2              1700.0   A3          D1
# 3               615.0   A4          D2
# 4              1700.0   A5          D3
# 5              1700.0   A6          D4
# 6              1700.0   A7          D5
# 7               517.0   A8          D6
# 8               713.0   B1          D7
# 9               253.0   B3          D8
# 10              785.0   B4          E1
# 11             1700.0   B5          E3
# 12              441.0   B6          E4
# 13             1700.0   B8          E5
# 14             1700.0   C1          E6
# 15             1700.0   C2          E8
# 16              412.0   C3          F1
# 17             1700.0   C4          F2
# 18             1405.0   C5          F3
# 19             1700.0   C6          F4
