# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Brenden APS Mesoporous silica nanoparticles data loading
#
# Requires Brenden's saxs_data_processing package to load Xenocs data files. Install here: https://github.com/pozzo-research-group/saxs_data_processing. Needs the `io` module.

# %%
from saxs_data_processing import io
import os
import pandas as pd
import numpy as np
import json
import glob

# %% [markdown]
# ## Load constants and filepaths
#
# There are 2 sets of SAXS data: Low-Q data collected at APS, and high-Q data measured at UW 11 days later. The UW data was collected on the same samples made at APS. This was done b/c the SAXS camera at APS was down. These sets of data are referred to as 'saxs' and 'usaxs' herein.
#
# Link to data: (must be added to share): https://drive.google.com/drive/folders/1E3q6wa394yXFD1YeCJbNZqaGLOP3RNGE?usp=drive_link

# %%
# Update this to point at the "Phasemap_data" directory you downloaded from google drive
data_root_fp = "/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data"

# %%
saxs_fp = f'{data_root_fp}/saxs' 
usaxs_fp = f'{data_root_fp}/usaxs'

# %%
saxs_paths = os.listdir(saxs_fp)
usaxs_paths = os.listdir(usaxs_fp)

# %%
sample_table = pd.read_csv(f'{data_root_fp}/APS_sample_reference_cartridgebatch.csv')

# %%
composition_table = pd.read_csv(f'{data_root_fp}/Mesoporous_SobolBaseline_APS_BatchMode_3_29_25.csv').set_index('uuid', drop=True)

# %%
with open(f'{data_root_fp}/Mesoporous_constants_APS_batch.json', 'rt') as f:
    constants = json.load(f)

# %%
def get_composition(row, teos_dilution_ratio, ctab_concentration, f127_concentration):
    teos_volume = row['teos_volume']
    ammonia_volume = row['ammonia_volume']
    water_volume = row['water_volume']
    ethanol_volume = row['ethanol_volume']
    ctab_volume = row['ctab_volume']
    F127_volume = row['F127_volume']

    total_volume = teos_volume + ammonia_volume + water_volume + ethanol_volume + ctab_volume + F127_volume
    print('Total volume: ', total_volume)
    
    ammonia_vf = ammonia_volume/total_volume
    water_delivered_vf = water_volume / total_volume
    ethanol_delivered_vf = ethanol_volume/total_volume
    ctab_vf = ctab_volume/total_volume
    F127_vf = F127_volume/total_volume


    ## Need to correct for mixed compositions

    # TEOS and ethanol:
    teos_vf = teos_volume/teos_dilution_ratio/total_volume
    teos_etoh_vf = teos_volume*((teos_dilution_ratio - 1)/teos_dilution_ratio)/total_volume

    ethanol_vf = ethanol_delivered_vf + teos_etoh_vf

    print('Ethanol delivered vf: ', ethanol_delivered_vf)
    print('Ethanol TEOS vf: ', teos_etoh_vf)
    print('Total ethanol vf: ', ethanol_vf)

    

    water_vf = water_delivered_vf + F127_vf + ctab_vf

    ctab_mass = ctab_volume * ctab_concentration
    f127_mass = F127_volume * f127_concentration

    # 

    return {'teos_vf':teos_vf, 'ammonia_vf':ammonia_vf, 'water_vf':water_vf, 'ethanol_vf':ethanol_vf, 'ctab_mass':ctab_mass, 'F127_mass':f127_mass}

# %%
def get_filename(stub, paths):
    for path in paths:
        if stub in path:
            return path

# %%
mesoporous_samples = {}
teos_dilution_ratio = constants['TEOS']['dilution_ratio']
ctab_concentration = constants['ctab']['stock_concentration_mg_uL']
f127_concentration = constants['f127']['stock_concentration_mg_uL']

for i, row in sample_table.iloc[0:73].iterrows(): #0:73 selected to not load samples that were not synthesized
    sample = {}
    sample['sample_name'] = row['Sample name']
    sample['cartridge_number'] = row['Cartridge plate']
    sample['cartridge_cell'] = row['Cartridge cell']
    sample_uid = row['Sample ID']


    if sample_uid is not np.nan:
        
        saxs_filename = glob.glob(os.path.join(saxs_fp, f'*{sample_uid}*'))
        usaxs_filename = glob.glob(os.path.join(usaxs_fp, f'*{sample_uid}*'))
        print(saxs_filename)
        if len(saxs_filename) == 0:
            print(f'Warning: No files found for sample {sample_uid}')
            continue
            
        sample['saxs_data'] = io.read_1D_data(saxs_filename[0])
        sample['usaxs_data'] = pd.read_csv(usaxs_filename[0], sep = '\t')


        composition_row = composition_table.loc[sample_uid]
        composition = get_composition(composition_row, teos_dilution_ratio, ctab_concentration, f127_concentration)
        sample['composition'] = composition
        mesoporous_samples[sample_uid] = sample
# Out:
# []
# Warning: No files found for sample 5dfdbe5e-3f38-44de-b9db-65c72c27f02e
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04247_A4-T2_93780a39-35f5-4c85-963b-2fde66396c78_000_sub_merged_merged.dat']
# Total volume:  9999.999992000001
# Ethanol delivered vf:  0.2721331681177065
# Ethanol TEOS vf:  0.03215435182396909
# Total ethanol vf:  0.3042875199416756
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04250_A5-T2_00afc63f-86d3-41a0-9f37-8d56c6d1abfd_000_sub_merged_merged.dat']
# Total volume:  9999.999992000001
# Ethanol delivered vf:  0.2721331681177065
# Ethanol TEOS vf:  0.03215435182396909
# Total ethanol vf:  0.3042875199416756
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04251_A6-T2_83caa81b-c9ac-4b2f-b7b6-97a05c42f277_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2101010853994405
# Ethanol TEOS vf:  0.053794442619034086
# Total ethanol vf:  0.2638955280184746
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04254_A7-T2_285271f3-055d-4edd-9cdd-3322ed1140ed_000_sub_merged_merged.dat']
# Total volume:  9999.999999999998
# Ethanol delivered vf:  0.1553807337944862
# Ethanol TEOS vf:  0.04799717765399256
# Total ethanol vf:  0.20337791144847875
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04257_A8-T2_8f86f557-5b97-4a80-b8da-55a55056d4b5_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.25170453586922964
# Ethanol TEOS vf:  0.05735260895146057
# Total ethanol vf:  0.3090571448206902
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04260_A9-T2_0491adba-e277-4475-aee0-af111005fd40_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2783210783864605
# Ethanol TEOS vf:  0.03703088856830727
# Total ethanol vf:  0.31535196695476775
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04263_A10-T2_586e06c8-0f02-43a3-9f2f-81e46d43ef64_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2034733824320836
# Ethanol TEOS vf:  0.018705457646329887
# Total ethanol vf:  0.2221788400784135
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04266_A11-T2_0ac06a89-aaee-42bd-b133-7ce04e6bf11f_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2512302360579837
# Ethanol TEOS vf:  0.006558151814294979
# Total ethanol vf:  0.2577883878722787
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04269_A12-T2_6ccabe6a-7601-4172-9afb-6028e52b540f_000_sub_merged_merged.dat']
# Total volume:  9999.999999999998
# Ethanol delivered vf:  0.32364452023897333
# Ethanol TEOS vf:  0.03122950597759337
# Total ethanol vf:  0.3548740262165667
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04272_B1-T2_a28ca6e8-5b6d-4d46-a3d1-69adf978666f_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.24824676706963222
# Ethanol TEOS vf:  0.07201819561845624
# Total ethanol vf:  0.32026496268808846
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04275_B2-T2_f2abcc4b-a35e-4ca7-9c30-dc187315c057_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.29666531453977807
# Ethanol TEOS vf:  0.06303921458174008
# Total ethanol vf:  0.3597045291215182
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04278_B3-T2_33751e55-4c10-44a5-b19d-41f69614c062_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.1739577046105871
# Ethanol TEOS vf:  0.05992318406009581
# Total ethanol vf:  0.2338808886706829
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04281_B4-T2_c5ce72e5-18c6-44cb-b802-1ee061e79d7c_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2501218261460774
# Ethanol TEOS vf:  0.021459221441019326
# Total ethanol vf:  0.2715810475870967
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04284_B5-T2_adaea14a-020d-4c48-969b-22082efaa360_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0
000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.19502917299715336
# Ethanol TEOS vf:  0.03343928498479072
# Total ethanol vf:  0.2284684579819441
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04398_E5-T2_9468480f-cc33-4439-b6de-28e0c91dfa88_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.18440245722350665
# Ethanol TEOS vf:  0.06267352274688892
# Total ethanol vf:  0.24707597997039557
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04401_E6-T2_143b74d3-8c43-49f1-98d2-7a8c3cc2f6b9_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.29776270568128677
# Ethanol TEOS vf:  0.042486508453823624
# Total ethanol vf:  0.3402492141351104
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04404_E7-T2_f19bdb3e-f1af-41a8-938a-0936963fe599_000_sub_merged_merged.dat']
# Total volume:  9999.999992000001
# Ethanol delivered vf:  0.2721331681177065
# Ethanol TEOS vf:  0.03215435182396909
# Total ethanol vf:  0.3042875199416756
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04407_E8-T2_47c3fdb1-9def-457d-9684-f0b8694433a5_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.32938184930153663
# Ethanol TEOS vf:  0.05040114236853551
# Total ethanol vf:  0.3797829916700721
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04410_E9-T2_4fac3f87-1504-4986-93d2-ae467c1ce9ba_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.21081973749299068
# Ethanol TEOS vf:  0.03143870917062741
# Total ethanol vf:  0.2422584466636181
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04413_E10-T2_196df7fe-a5e9-4d8c-b753-9d00abb0051a_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.28697877485775397
# Ethanol TEOS vf:  0.07011202446646059
# Total ethanol vf:  0.35709079932421456
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04416_E11-T2_ef877122-20a5-4286-bb7a-14bf7d0e7c45_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.36621913858265615
# Ethanol TEOS vf:  0.018380719194700943
# Total ethanol vf:  0.3845998577773571
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04419_E12-T2_c9299417-9548-4fff-92d8-b9c68e488e3c_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2569163382122992
# Ethanol TEOS vf:  0.06537396292437334
# Total ethanol vf:  0.32229030113667256
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04422_F1-T2_a8e7d7a2-13f6-4bbf-8106-048dc5a40ec7_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.24157976083792745
# Ethanol TEOS vf:  0.036193259578570725
# Total ethanol vf:  0.2777730204164982
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04425_F2-T2_8776a309-5ce2-4cb7-afae-4cd761dcfef9_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.23859879866188857
# Ethanol TEOS vf:  0.058074712493061086
# Total ethanol vf:  0.29667351115494967
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04428_F3-T2_25f01505-5668-4804-ab0f-06cdd395dd93_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.18932516542626546
# Ethanol TEOS vf:  0.019647794166672974
# Total ethanol vf:  0.20897295959293843
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04431_F4-T2_75c6771e-9849-4186-9339-6bc385c37e95_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.1669167024015449
# Ethanol TEOS vf:  0.06913809078494088
# Total ethanol vf:  0.23605479318648578
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04434_F5-T2_b989e35a-cbc7-49a2-a1b7-fc0b74e2b0ef_000_sub_merged_merged.dat']
# Total volume:  10000.0
# Ethanol delivered vf:  0.2257320547813084
# Ethanol TEOS vf:  0.04797736253947951
# Total ethanol vf:  0.2737094173207879
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/Phasemap_data/saxs/04437_F6-T2_5bc780b1-7565-40b3-a3e6-ab28ae987cd2_000_sub_merged_merged.dat']

# %% [markdown]
# mesoporous_samples is a dictionary containing composition and scattering information for each sample. It's structure is:
#
# sample_uid:
# - sample_name
# - cartridge_number
# - cartridge_cell
# - saxs_data (tuple, (Pandas dataframe of scattering, metadata))
# - usaxs_data (Pandas dataframe with Q, I, ISigma)
# - composition - dictionary of component name to value
