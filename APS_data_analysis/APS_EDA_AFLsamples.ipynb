# %%
from saxs_data_processing import io
import matplotlib.pyplot as plt
import os
import pandas as pd
import numpy as np
import json
from matplotlib.backends.backend_pdf import PdfPages

import sys
sys.path.append('../../silica_opt_insilico/src/silica_opt_insilico/')
import pd_utils
import matplotlib.ticker as ticker

# %% [markdown]
# ## Load constants and filepaths

# %%
with open('../APS/Mesoporous_constants_APS_batch.json', 'rt') as f:
    constants = json.load(f)

# %%
data_fp = "/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/AFLSamples_emptyblank_reduced"

# %%
paths = os.listdir(data_fp)

# %%
# load usaxs data

# %%
#sample_table = pd.read_csv("/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/APS_Beamtime_Sp25/APS_sample_reference_cartridgebatch.csv")

# %%
#omposition_table = pd.read_csv('../APS/Mesoporous_SobolBaseline').set_index('uuid', drop=True)

# %%
scattering
# Out:
#      Qvector_A     Intensity    Uncertainty
# 0     0.000123  3.067115e+06  190241.114741
# 1     0.000131  2.864538e+06  288901.375000
# 2     0.000136  2.811283e+06  275276.343750
# 3     0.000140  2.753588e+06  261195.906250
# 4     0.000144  2.687398e+06  253563.812500
# ..         ...           ...            ...
# 495   0.281843  1.317800e+01       0.387480
# 496   0.285767  1.357776e+01       0.384209
# 497   0.289765  1.279766e+01       0.382479
# 498   0.293797  1.393507e+01       0.386160
# 499   0.297823  1.214471e+01       0.384893
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Plot scattering

# %%
### Plot the one nice one

# %%
for path in paths:
    scattering = pd.read_csv(os.path.join(data_fp, path), sep = '\t')
    name = '_'.join(path.split('_')[:2])
    fig, ax = plt.subplots()
    ax.loglog(scattering['Qvector_A'], scattering['Intensity'], marker = '.', ls = '')
# Out:
# /tmp/ipykernel_3172/608708677.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
