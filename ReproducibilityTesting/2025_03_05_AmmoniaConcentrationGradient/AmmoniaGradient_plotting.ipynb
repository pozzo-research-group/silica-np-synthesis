# %%
diameters = [139, 112, 85, 65, 49]
volume_fractions = [0.018891, 0.016391000000000003, 0.013891, 0.011391000000000002, 0.008891000000000001]

# %%
plt.scatter(volume_fractions, diameters)
plt.xlim([0, 0.02])
plt.ylim([0, 150])
plt.xlabel('Ammonium hydroxide volume fraction')
plt.ylabel('Particle diameter [nm]')
plt.savefig('ammonia_gradient_plot.png', dpi = 300)

# %%
plt.xlim([0, 0.02])
# Out:
# (0.0, 0.02)
