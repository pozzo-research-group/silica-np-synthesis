# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests

# ----------- Science Jubilee -------------
from science_jubilee import Machine as Jub
from science_jubilee.tools import HTTPSyringe as syringe
from science_jubilee.tools import Pipette
from science_jubilee.utils import Handlers
import time
import numpy as np
import pandas as pd
import logging
import sys
sys.path.append('../..')
import stober_synthesis_utils as stober

# %%
FORMAT = '%(asctime)s:%(levelname)s:%(name)s:%(message)s'
logging.basicConfig(filename = '2025_01_22_OptRound2_RandomInit.log', level = logging.INFO, format = FORMAT)
logger = logging.getLogger(__name__)

# %%
jubilee = Jub.Machine(address='192.168.1.2', simulated = False, crash_detection = False)

# %% [raw]
# #jubilee.home_all()
# logger.info('Homed Jubilee')

# %%
deck = jubilee.load_deck('lab_automation_deck_AFL_bolton.json')

# %%
sample_table = pd.read_csv('SampleTable_RandomSobol_2025_01_13.csv')

# %%
stober.count_stock_vials(sample_table, 15000)
# Out:
# {'teos_count': 1, 'ammonia_count': 1, 'water_count': 1, 'ethanol_count': 2}

# %%
sample_table['teos_volume'].sum()
# Out:
# 8139.599993141368

# %%
sample_table['ethanol_dilute_vol'] = 1700*(1-sample_table['dilution_volume_fraction'])
sample_table['sample_dilute_vol'] = 1700*(sample_table['dilution_volume_fraction'])

# %%
sample_table[sample_table['ethanol_dilute_vol']>0]['ethanol_dilute_vol'].sum()/10000
# Out:
# 2.5303091038954646

# %%
sample_table
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  c563cb4d-d727-437f-9a6a-fef3eccbbe50   222.617091
# 1            1  3ef8b92f-f2eb-4134-ad6c-ae3329408457   424.578425
# 2            2  0507cf19-673b-4d6b-922e-c21f718ad4fe   290.225034
# 3            3  82fc5e1c-5d6e-4ecd-82c3-eb912535a0d7    87.221241
# 4            4  9964ab9f-5b01-4ae2-b492-a1be55ce083f    44.198312
# 5            5  d263a9a8-70c2-49a4-badb-03a72fa16632   362.014946
# 6            6  586ae478-4dab-4d7d-9382-ab359a49387a   467.857264
# 7            7  7386215f-7150-48a6-b35f-96cbe5b743cf   150.571271
# 8            8  d408858a-bbae-4227-8e64-6c368a1f3398   171.120992
# 9            9  0c042bd5-e5ed-4460-9bb9-d8556dba293c   429.271862
# 10          10  8fbd8649-0d61-4edc-9fe3-1ca354becc5a   333.626846
# 11          11  d4ebf798-d856-406f-9732-f11da412170b    76.238493
# 12          12  e44ddf37-b7d0-420b-bf6c-02535ca6803a   119.513820
# 13          13  238ebc43-fbc1-4049-b506-1dc041dedb42   261.584537
# 14          14  8aacf82b-9869-48dd-ad8a-85eaca6ce824   386.245420
# 15          15  a635324c-8eea-4566-af05-e39d8101ef91   242.914414
# 16          16  08f1d123-975c-4dca-b962-6134f27e4ddc   233.761094
# 17          17  d91aa15e-1296-4485-94d0-0cf924b116de   377.418571
# 18          18  1537344f-106d-4cb9-b1de-3262334f8665   270.874818
# 19          19  7c2bc3ea-ff76-42ba-88f9-86fb14a0f437   128.203724
# 20          20  1ec7142f-1f4f-44ee-965b-da3a052e0b2a    56.185982
# 21          21  13735048-3ac7-447e-8bca-7af4fda689cb   314.125550
# 22          22  f041b533-6c1d-4be3-aa7b-01521b804bf8   449.236588
# 23          23  1c5c16fb-5f52-451d-a370-36a6418ab246   190.710085
# 24          24  0a4b4bec-376d-4106-853e-53c50b36e515   159.850139
# 25          25  ee885bbe-4e05-426d-9772-0e1e3293e727   476.556825
# 26          26  da675871-7139-4a31-8e76-317fb87385fa   352.880060
# 27          27  9f769eed-2173-4aa3-b71b-60f6488e526f    35.354782
# 28          28  c62bf89a-0e46-4e1c-9e83-89c38787a58e   107.176312
# 29          29  77c8bfe5-d105-433e-8fcc-12675094a30e   309.825540
# 30          30  fa064c37-87e6-4f7f-9189-02b4ddf6dd6e   404.542595
# 31          31  4808d774-6c9b-4436-86ed-5355d9731910   203.097360
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
#
# 25         26.474566              0.031826   D4         1314.210862
# 26         19.603846              0.024214   D5         1179.000184
# 27          1.964094              0.002415   D6        -3500.157891
# 28          5.954057              0.007204   D7          -15.401881
# 29         17.212001              0.021203   D8         1106.600094
# 30         22.473898              0.027088   E1         1245.535010
# 31         11.282840              0.014001   E3          794.766931
#
#     sample_dilute_vol
# 0          825.859530
# 1          433.018815
# 2          633.475493
# 3         2107.863216
# 4         4159.671187
# 5          507.853194
# 6          392.962684
# 7         1221.019421
# 8         1074.388620
# 9          428.284411
# 10         551.066105
# 11        2411.517320
# 12        1538.319558
# 13         702.833772
# 14         475.993855
# 15         756.852766
# 16         786.488647
# 17         487.126127
# 18         678.728454
# 19        1434.049188
# 20        3272.176417
# 21         585.276959
# 22         409.250830
# 23         964.031067
# 24        1150.142549
# 25         385.789138
# 26         520.999816
# 27        5200.157891
# 28        1715.401881
# 29         593.399906
# 30         454.464990
# 31         905.233069

# %% [markdown]
# ## Load Tools

# %%
syringe_10 = syringe.HTTPSyringe.from_config(2, "../../../science-jubilee/src/science_jubilee/tools/configs/10cc_syringe.json")
syringe_1_1 = syringe.HTTPSyringe.from_config(1, "../../../science-jubilee/src/science_jubilee/tools/configs/1cc_1_syringe.json")
syringe_1_2 = syringe.HTTPSyringe.from_config(3, "../../../science-jubilee/src/science_jubilee/tools/configs/1cc_2_Hamiltonsyringe.json")
syringe_1_3 = syringe.HTTPSyringe.from_config(4, "../../../science-jubilee/src/science_jubilee/tools/configs/1cc_3_Hamiltonsyringe.json")
# Out:
# Syringe name:  10cc_1
# {'capacity': 10000, 'empty_position': 1830, 'full_position': 1217, 'name': '10cc_1'}
# Syringe name:  1cc_1
# {'capacity': 1000, 'empty_position': 1845, 'full_position': 1240, 'name': '1cc_1'}
# Syringe name:  1cc_2_hamilton
# {'capacity': 1000, 'empty_position': 1753, 'full_position': 1120, 'name': '1cc_2_hamilton'}
# Syringe name:  1cc_3_hamilton
# {'capacity': 1000, 'empty_position': 1753, 'full_position': 1120, 'name': '1cc_3_hamilton'}

# %%
jubilee.load_tool(syringe_10)
jubilee.load_tool(syringe_1_1)
jubilee.load_tool(syringe_1_2)
jubilee.load_tool(syringe_1_3)

# %%
mix_syringe = syringe_10
water_syringe = syringe_1_1
ammonia_syringe = syringe_1_2
teos_syringe = syringe_1_3

# %%
syringe_10.name
# Out:
# '10cc_1'

# %% [markdown]
# ## Load water syringe with water

# %%
water_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
water_syringe.set_pulsewidth(water_syringe.empty_position-1, s = 2000)

# %%
water_syringe.set_pulsewidth(water_syringe.full_position+1, s = 500)

# %%
water_syringe.set_pulsewidth(water_syringe.full_position+150, s = 500)

# %%
water_syringe.load_syringe(740, water_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 740 uL

# %% [markdown]
# ## Load ammonia syringe

# %%
#ammonia_syringe.set_pulsewidth(1420, s = 10)

# %%
ammonia_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.empty_position-1, s = 2000)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+1, s = 10)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+150, s = 500)

# %%
ammonia_syringe.load_syringe(730, ammonia_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 730 uL

# %% [markdown]
# ## Load TEOS syringe

# %%
teos_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
teos_syringe.set_pulsewidth(teos_syringe.empty_position-1, s = 2000)

# %%
teos_syringe.set_pulsewidth(teos_syringe.full_position+1, s = 500)

# %%
teos_syringe.set_pulsewidth(teos_syringe.full_position+200, s = 200)

# %%
teos_syringe.load_syringe(690, teos_syringe.full_position+200)
# Out:
# Loaded syringe, remaining volume 690 uL

# %% [markdown]
# ## load ethanol syringe

# %%
#jubilee.park_tool()

# %%
mix_syringe.load_syringe(0, mix_syringe.empty_position-1)
# Out:
# Loaded syringe, remaining volume 0 uL

# %%
mix_syringe.set_pulsewidth(mix_syringe.empty_position-1, s = 2000)

# %%
mix_syringe.set_pulsewidth(mix_syringe.full_position+1, s = 5000)

# %%
#mix_syringe.empty_position

# %%
mix_syringe.set_pulsewidth(mix_syringe.full_position+150, s = 500)

# %%
mix_syringe.load_syringe(7300, mix_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 7300 uL

# %% [markdown]
# ## Load labware

# %%
samples = jubilee.load_labware('septavialrev1_44_holder_2000ul.json', 2)
samples.manual_offset([(18.1, 175.4), (131.1, 176.4), (132.1,  106.6)])
# Out:
# New manual offset applied to septavialrev1_44_holder_2000ul

# %%
samples_dilute = jubilee.load_labware('septavialrev1_44_holder_2000ul.json', 3)
samples_dilute.manual_offset([(158.9, 175.6), (270.8, 176.2), (270.8, 106.9)])
# Out:
# New manual offset applied to septavialrev1_44_holder_2000ul

# %%
stocks_main = jubilee.load_labware('20ccscintillation_screwdown_vialplate.json', 4)
stocks_main.manual_offset([(29.8, 265.1), (119.8, 266.1), (119.8, 210.1)])
# Out:
# New manual offset applied to 20ccscintillation_screwdown_vialplate

# %%
trash = jubilee.load_labware('agilent_1_reservoir_290ml.json', 1)

# %%
teos_stocks = [stocks_main[0]]
ammonia_stocks = [stocks_main[1]]
water_stocks = [stocks_main[2]]
ethanol_stocks = [stocks_main[3], stocks_main[4], stocks_main[5], stocks_main[6], stocks_main[7], stocks_main[8]]
rinse_stocks = [stocks_main[9], stocks_main[10], stocks_main[11]]

# %% [markdown]
# ## Check sample alignment

# %%
jubilee.park_tool()

# %%
jubilee.pickup_tool(teos_syringe)
for i, row in sample_table.iterrows():
    loc = samples_dilute[row['well']]
    jubilee.move_to(x = loc.x, y = loc.y)
    print(loc.y)
    jubilee.move_to(z = loc.top_+7)
    curr_well = row['well']
    ans = input(f'Is the tip centered over sample {curr_well}?')
    if ans == 'y':
        continue
    else:
        continue
# Out:
# 175.6
# Is the tip centered over sample A1?
# 175.6428572968741
# Is the tip centered over sample A2?
# 175.6857145937482
# Is the tip centered over sample A3?
# 175.7285718906223
# Is the tip centered over sample A4?
# 175.7714291874964
# Is the tip centered over sample A5?
# 175.8142864843705
# Is the tip centered over sample A6?
# 175.85714378124462
# Is the tip centered over sample A7?
# 175.90000107811872
# Is the tip centered over sample A8?
# 161.74004980890416
# Is the tip centered over sample B1?
# 161.82576440265237
# Is the tip centered over sample B3?
# 161.86862169952644
# Is the tip centered over sample B4?
# 161.91147899640055
# Is the tip centered over sample B5?
# 161.95433629327465
# Is the tip centered over sample B6?
# 162.04005088702286
# Is the tip centered over sample B8?
# 147.8800996178083
# Is the tip centered over sample C1?
# 147.9229569146824
# Is the tip centered over sample C2?
# 147.9658142115565
# Is the tip centered over sample C3?
# 148.0086715084306
# Is the tip centered over sample C4?
# 148.0515288053047
# Is the tip centered over sample C5?
# Is the tip centered over sample C6?
# 148.09438610217882
# 148.13724339905292
# Is the tip centered over sample C7?
# 148.18010069592702
# Is the tip centered over sample C8?
# 134.02014942671246
# Is the tip centered over sample D1?
# 134.06300672358657
# Is the tip centered over sample D2?
# 134.10586402046067
# Is the tip centered over sample D3?
# 134.14872131733478
# Is the tip centered over sample D4?
# 134.19157861420888
# Is the tip centered over sample D5?
# 134.23443591108298
# Is the tip centered over sample D6?
# 134.2772932079571
# Is the tip centered over sample D7?
# 134.3201505048312
# Is the tip centered over sample D8?
# 120.16019923561663
# Is the tip centered over sample E1?
# 120.24591382936484
# Is the tip centered over sample E3?

# %%
samples_apdist['A1'].y

# %%
jubilee.park_tool()

# %% [markdown]
# # Experiment

# %%
location_lookup = {row['uuid']:samples[row['well']] for i, row in sample_table.iterrows()}

# %%
sample_table['ethanol_volume'].sum()
# Out:
# 26105.202888567

# %%
location_lookup_dilute = {}

for i, row in sample_table.iterrows():
    uuid_val = row['uuid']
    well = row['well']
    if well is not np.nan:
        well_loc = samples_dilute[well]
    else:
        well_loc = None

    location_lookup_dilute[uuid_val] = well_loc

# %%
mix_syringe.dispense(500, trash[0])

# %%
sample_table.iloc[7:]
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 7            7  7386215f-7150-48a6-b35f-96cbe5b743cf   150.571271
# 8            8  d408858a-bbae-4227-8e64-6c368a1f3398   171.120992
# 9            9  0c042bd5-e5ed-4460-9bb9-d8556dba293c   429.271862
# 10          10  8fbd8649-0d61-4edc-9fe3-1ca354becc5a   333.626846
# 11          11  d4ebf798-d856-406f-9732-f11da412170b    76.238493
# 12          12  e44ddf37-b7d0-420b-bf6c-02535ca6803a   119.513820
# 13          13  238ebc43-fbc1-4049-b506-1dc041dedb42   261.584537
# 14          14  8aacf82b-9869-48dd-ad8a-85eaca6ce824   386.245420
# 15          15  a635324c-8eea-4566-af05-e39d8101ef91   242.914414
# 16          16  08f1d123-975c-4dca-b962-6134f27e4ddc   233.761094
# 17          17  d91aa15e-1296-4485-94d0-0cf924b116de   377.418571
# 18          18  1537344f-106d-4cb9-b1de-3262334f8665   270.874818
# 19          19  7c2bc3ea-ff76-42ba-88f9-86fb14a0f437   128.203724
# 20          20  1ec7142f-1f4f-44ee-965b-da3a052e0b2a    56.185982
# 21          21  13735048-3ac7-447e-8bca-7af4fda689cb   314.125550
# 22          22  f041b533-6c1d-4be3-aa7b-01521b804bf8   449.236588
# 7         1221.019421
# 8         1074.388620
# 9          428.284411
# 10         551.066105
# 11        2411.517320
# 12        1538.319558
# 13         702.833772
# 14         475.993855
# 15         756.852766
# 16         786.488647
# 17         487.126127
# 18         678.728454
# 19        1434.049188
# 20        3272.176417
# 21         585.276959
# 22         409.250830
# 23         964.031067
# 24        1150.142549
# 25         385.789138
# 26         520.999816
# 27        5200.157891
# 28        1715.401881
# 29         593.399906
# 30         454.464990
# 31         905.233069

# %% [markdown]
# ## add ethanol

# %%
stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, sample_table.iloc[7:], location_lookup, 'ethanol_volume', ethanol_stocks[:3], stocks_usable_volume=15000, dwell_time = 10)

# %%
#dispense remaining volume from etOH mix syringe
jubilee.pickup_tool(mix_syringe)
mix_syringe.dispense(mix_syringe.remaining_volume-1, trash[0])
logger.info('Emptied ethanol syringe into trash')
jubilee.park_tool()

# %%
mix_syringe.set_pulsewidth(mix_syringe.empty_position-1)

# %% [markdown]
# ## Dispense water

# %%
stober.add_reactants_batch(jubilee, water_syringe, mix_syringe, sample_table, location_lookup, 'water_volume', water_stocks, dwell_time = 7)

# %% [markdown]
# ## dispense Ammonia

# %%
stober.add_reactants_batch(jubilee, ammonia_syringe, mix_syringe, sample_table, location_lookup, 'ammonia_volume', ammonia_stocks)

# %% [markdown]
# ## mix precursors

# %%
stober.first_mix(jubilee, mix_syringe, 2000, location_lookup, rinse_stocks, 5)

# %% [markdown]
# ## Add TEOS and mix

# %%
teos_start_time = time.time()

# %%
stober.add_reactants_batch(jubilee, teos_syringe, mix_syringe, sample_table, location_lookup, 'teos_volume', teos_stocks, mix_after=(2000, 5, rinse_stocks))

# %% [markdown]
# ### Dilution

# %%
hrs5 = 60*60*5
while (time.time() - teos_start_time) < hrs5:
    time.sleep(60)

#dispese ethanol into dilution vials
stober.add_reactants_batch(jubilee, mix_syringe, mix_syringe, sample_table, location_lookup_dilute, 'ethanol_dilute_vol', ethanol_stocks[4:], stocks_usable_volume=15000, dwell_time = 10)

jubilee.pickup_tool(mix_syringe)
mix_syringe.dispense(mix_syringe.remaining_volume-1, trash[0])
logger.info('Emptied ethanol syringe into trash')
jubilee.park_tool()

jubilee.pickup_tool(mix_syringe)
rinse_vol = 2000
for i, row in sample_table.iterrows():
    uuid_val = row['uuid']
    sample_well = location_lookup[uuid_val]
    dilute_well = location_lookup_dilute[uuid_val]
    if dilute_well is None:
        continue
    else:
        vol = row['sample_dilute_vol']
        
        mix_syringe.aspirate(vol, sample_well.bottom(+5))
        time.sleep(10)
        mix_syringe.dispense(vol, dilute_well.bottom(+5))
        time.sleep(10)
        logger.info(f'Transferred {vol} uL from {sample_well} to {dilute_well}')
    
        for stock in rinse_stocks:
            mix_syringe.mix(rinse_vol, 5, stock.bottom(+10), t_hold = 3, s_aspirate = 2000, s_dispense = 500)
    
        logger.info(f'Washed mix syringe in wash solutions {rinse_stocks}')

# %%
location_lookup_dilute
# Out:
# {'c563cb4d-d727-437f-9a6a-fef3eccbbe50': Well A1 form septavialrev1_44_holder_2000ul on slot 3,
#  '3ef8b92f-f2eb-4134-ad6c-ae3329408457': Well A2 form septavialrev1_44_holder_2000ul on slot 3,
#  '0507cf19-673b-4d6b-922e-c21f718ad4fe': Well A3 form septavialrev1_44_holder_2000ul on slot 3,
#  '82fc5e1c-5d6e-4ecd-82c3-eb912535a0d
# 0          17.438158              0.021680              1114.0
# 1          12.625702              0.015594               891.0
# 2          10.032124              0.012533               682.0
# 3          10.943851              0.013300               767.0
# 4          40.373762              0.048714              1447.0
# 5           2.691584              0.003253                 0.0
# 6           2.691584              0.003233                 0.0
# 7          12.147907              0.014542               859.0
# 8           2.691584              0.003226                 0.0
# 9          40.373762              0.049492              1447.0
# 10         16.706755              0.020307              1089.0
# 11          2.691584              0.003356                 0.0
# 12         24.644612              0.029719              1286.0
# 13         10.792990              0.013006               754.0
# 14         15.123657              0.018752              1025.0
# 15          7.719435              0.009435               377.0
# 16          2.691584              0.003377                 0.0
# 17         40.373762              0.047823              1447.0
# 18         17.827756              0.021965              1127.0
# 19         14.114872              0.017193               976.0
#
#     sample_dilute_vol well dilute_well
# 0               586.0   A1          C7
# 1               809.0   A2          C8
# 2              1018.0   A3          D1
# 3               933.0   A4          D2
# 4               253.0   A5          D3
# 5              1700.0   A6          D4
# 6              1700.0   A7          D5
# 7               841.0   A8          D6
# 8              1700.0   B1          D7
# 9               253.0   B3          D8
# 10              611.0   B4          E1
# 11             1700.0   B5          E3
# 12              414.0   B6          E4
# 13              946.0   B8          E5
# 14              675.0   C1          E6
# 15             1323.0   C2          E8
# 16             1700.0   C3          F1
# 17              253.0   C4          F2
# 18              573.0   C5          F3
# 19              724.0   C6          F4

# %%
sample_table_rmse
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  4aea3a58-a85b-42e6-bc69-aa5692cd7675   172.931279
# 1            1  03662924-3f8e-42e5-bd45-75fe757a3692   131.076677
# 2            2  bd1fe8eb-8834-4c41-9d4d-37c85d39a7d3   154.993822
# 3            3  2b52886d-aad5-4919-a877-25f98e29b245   243.006866
# 4            4  080f2aff-554d-434f-a78c-d6072afeabc2   245.898840
# 5            5  853457e3-042a-45a5-9dd9-4d50873e8801    32.411517
# 6            6  a42e6635-5215-4632-80a5-b635e6102482    17.000000
# 7            7  e4270ccf-97f1-4bad-821d-6c5019a2dfa0    69.863716
# 8            8  fc10b4a6-f126-4443-bcd8-92514ee12e3b    76.588665
# 9            9  40c911a0-8f77-481a-a569-d2d487717d2f    67.955414
# 10          10  fe4236d3-649c-411e-924c-fb7fba84e18d    82.079003
# 11          11  764460ac-e597-4ed1-bffa-d0dc0cad76d0   148.236797
# 12          12  627f3c3e-bad8-4762-9393-fa96e29ddb25    17.000000
# 13          13  b06a777a-cb51-4c34-81f7-a6c383a0d41f    17.000000
# 14          14  efa89b9c-f4e2-4088-ac1a-5bb66cf814b6    65.960939
# 15          15  7156004c-7899-4c52-be69-020024e1c7c7    34.776849
# 16          16  eb5462d6-cfff-4947-afc7-1245fb0851ff    20.573972
# 17          17  1db061ce-197d-455c-bffb-539e4be3a76d   186.596587
# 18          18  0d94ce6b-b9e1-4a27-a875-a52193d82555    92.069351
# 19          19  58c36940-4c76-4e8d-bc15-ff110d639176   241.331713
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0         8.500000     89.141196     1429.427525                  0.219431
# 1         8.755210    242.524165     1317.643948                  0.289498
# 2       151.000072     23.471911     1370.534195                  0.244825
# 3        26.038005    162.100125     1268.855005                  0.156154
# 4        14.346618    128.395161     1311.359381                  0.154317
# 5        65.008919    255.000010     1347.579554                  1.170770
# 6        74.895387      8.500000     1599.604613                  2.232143
# 7        58.148577     71.332869     1500.654837                  0.543149
# 8       172.622596    184.226452     1266.562287                  0.495458
# 9       144.173409    194.706745     1293.164431                  0.558402
# 10       71.156324     30.083733     1516.680939                  0.462316
# 11       84.451798    128.629026     1338.682379                  0.255985
# 12       53.660974     72.254276     1557.084751                  2.232143
# 13       61.447598     97.872735     1523.679667                  2.232143
# 14       55.478980    142.232853     1436.327228                  0.575286
# 15      159.386691    166.240472     1339.595989                  1.091141
# 16       82.109325      8.500000     1588.816703                  1.844390
# 17       24.094311     51.902390     1437.406712                  0.203361
# 18       18.110821     50.289497     1539.530331                  0.412150
# 19      106.611956    197.227277     1154.829054                  0.157238
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0          27.379945              0.033576              1327.0
# 1          20.753170              0.024980              1208.0
# 2          24.539935              0.030105              1284.0
# 3          38.474905              0.046271              1435.0
# 4          38.932787              0.047086              1438.0
# 5           5.131666              0.006200                 0.0
# 6           2.691584              0.003379                 0.0
# 7          11.061415              0.013694               777.0
# 8          12.126166              0.014615               858.0
# 9          10.759277              0.012988               751.0
# 10         12.995443              0.016152               914.0
# 11         23.470105              0.028511              1265.0
# 12          2.691584              0.003351                 0.0
# 13          2.691584              0.003336                 0.0
# 14         10.443495              0.012799               722.0
# 15          5.506165              0.006690                 0.0
# 16          3.257446              0.004085                 0.0
# 17         29.543552              0.036337              1354.0
# 18         14.577200              0.018121               999.0
# 19         38.209681              0.045436              1433.0
#
#     sample_dilute_vol well dilute_well
# 0               373.0   A1          C7
# 1               492.0   A2          C8
# 2               416.0   A3          D1
# 3               265.0   A4          D2
# 4               262.0   A5          D3
# 5              1700.0   A6          D4
# 6              1700.0   A7          D5
# 7               923.0   A8          D6
# 8               842.0   B1          D7
# 9               949.0   B3          D8
# 10              786.0   B4          E1
# 11              435.0   B5          E3
# 12             1700.0   B6          E4
# 13             1700.0   B8          E5
# 14              978.0   C1          E6
# 15             1700.0   C2          E8
# 16             1700.0   C3          F1
# 17              346.0   C4          F2
# 18              701.0   C5          F3
# 19              267.0   C6          F4

# %%
dilution_table_apdist
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  bbd1bfff-7563-4360-b5b8-86a1deb3928f    91.455773
# 1            1  5b9ac046-6ca6-4ebc-87f3-e272edaedb7b   140.351853
# 2            2  9f782755-5ca4-4466-a1f1-a87ef665ed22   255.000010
# 3            3  f8b2207f-b63c-44d9-8fe4-70639fdd3f5c   255.000010
# 4            4  61431cc9-9557-45af-82c4-9e7acb251717    78.545307
# 5            5  e773e91e-cdd8-466c-be37-8ff86cb7f610    52.806463
# 6            6  4559d494-fcc2-4dfc-a4cf-a14d93eb0029   102.107158
# 7            7  78e5ec30-0b59-4536-a9e0-21b4bac433a8    67.497684
# 8            8  e42bc4d2-0157-425c-aed0-4cdec425d9ab   120.342861
# 9            9  4133ded3-a2c0-4d14-b4fb-578358436a04    17.000000
# 10          10  79149445-b04e-499f-bfa2-362ba81c3121    72.795379
# 11          11  f2aac2f9-31c5-4eaf-be0b-ed9c1ec48ac4   105.384178
# 12          12  97be35cc-6af5-4906-a5ec-6c5ab5836951   104.194804
# 13          13  6f651325-aa30-4e15-a8b8-8550752155de    17.000000
# 14          14  884360fc-1d5b-45f3-b018-3a687b81f8a7   190.498775
# 15          15  45d13e36-5ae6-4aba-a657-a6cce9fb8db6    61.079639
# 16          16  76e61e49-8d12-493d-aa0e-e367cf9222a1   125.772466
# 17          17  cb91c3d6-d0df-437e-a504-7433689fb381    17.000000
# 18          18  2ef2ca93-424e-4bab-ab05-e1a4a365afc9   140.084917
# 19          19  2c2e06ba-fd0d-4b67-ac27-94a71a40985c   154.968959
#
#     ammonia_volume  water_volume  ethanol_volume  dilution_volume_fraction  \
# 0       121.416734    255.000010     1232.127483                  0.414916
# 1         8.500000    255.000010     1296.148137                  0.270366
# 2        42.990994    255.000010     1147.008985                  0.148810
# 3        53.976205      8.500000     1382.523785                  0.148810
# 4        77.696470    193.651897     1350.106326                  0.483115
# 5        59.674126     39.147849     1548.371562                  0.718594
# 6       177.169546      8.500000     1412.223295                  0.371633
# 7       128.016714      8.500000     1495.985602                  0.562189
# 8       146.735320    171.336467     1261.585352                  0.315319
# 9       159.878042      8.500000     1514.621958                  2.232143
# 10       70.436200      8.500000     1548.268421                  0.521275
# 11       88.456498    250.912468     1255.246855                  0.360077
# 12      128.661020      8.500000     1458.644176                  0.364187
# 13      186.999999      8.500000     1487.500002                  2.232143
# 14       74.557186    157.476255     1277.467784                  0.199195
# 15      133.803360    255.000010     1250.116991                  0.621262
# 16      186.999999     49.355634     1337.871901                  0.301707
# 17      186.999999    255.000010     1240.999991                  2.232143
# 18       99.182012     28.917468     1431.815603                  0.270882
# 19      133.155064    199.449208     1212.426769                  0.244865
#
#     silica_mass_conc  silica_mass_fraction  ethanol_dilute_vol  \
# 0          14.480053              0.017314               995.0
# 1          22.221694              0.026673              1240.0
# 2          40.373762              0.047775              1447.0
# 3          40.373762              0.049511              1447.0
# 4          12.435958              0.015077               879.0
# 5           8.360767              0.010419               478.0
# 6          16.166470              0.019945              1068.0
# 7          10.686805              0.013285               744.0
# 8          19.053701              0.022952              1164.0
# 9           2.691584              0.003355                 0.0
# 10         11.525581              0.014387               814.0
# 11         16.685316              0.019986              1088.0
# 12         16.497004              0.020429              1081.0
# 13          2.691584              0.003348                 0.0
# 14         30.161380              0.036354              1361.0
# 15          9.670646              0.011588               644.0
# 16         19.913362              0.024338              1187.0
# 17          2.691584              0.003226                 0.0
# 18         22.179431              0.027342              1240.0
# 19         24.535998              0.029362              1284.0
#
#     sample_dilute_vol well dilute_well
# 0               705.0   C7          C7
# 1               460.0   C8          C8
# 2               253.0   D1          D1
# 3               253.0   D2          D2
# 4               821.0   D3          D3
# 5              1222.0   D4          D4
# 6               632.0   D5          D5
# 7               956.0   D6          D6
# 8               536.0   D7          D7
# 9              1700.0   D8          D8
# 10              886.0   E1          E1
# 11              612.0   E3          E3
# 12              619.0   E4          E4
# 13             1700.0   E5          E5
# 14              339.0   E6          E6
# 15             1056.0   E8          E8
# 16              513.0   F1          F1
# 17             1700.0   F2          F2
# 18              460.0   F3          F3
# 19              416.0   F4          F4
