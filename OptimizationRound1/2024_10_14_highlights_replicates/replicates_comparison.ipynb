# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import numpy as np
import saxs_data_processing
from saxs_data_processing import io
from saxs_data_processing import manipulate
import glob
import shutil

# %% [markdown]
# ### Load uuid mapping table

# %%
with open('replicate_sample_uuid_mapper.json', 'rt') as f:
    uuid_mapping = json.load(f)

# %%
uuid_mapping
# Out:
# {'4bec4e18-80bb-44d9-8508-cc464f14b287': '4fd21940-a331-4524-b730-cf76de1b4d8d',
#  '3584700a-8b01-4e59-a53a-1300fd3fac0a': '8933d4b1-8929-4b58-a491-a0c55df30fed',
#  'fed3ab35-04e9-4916-8527-8627191a3bdc': '130093e4-2947-4d37-b73a-ed4c23442ab8',
#  '32ec16b1-c5b5-4d8b-b396-cd1ad4b740d9': 'a3f7d49b-cc77-4468-aae0-ad451027ddc0',
#  '770a433d-0480-4cee-bf12-ce066c24db55': 'f69628da-ff56-4f3a-ba2e-816036b87557',
#  '23850c30-c572-41ad-abf0-7e1bd4fa7397': 'eb5c038c-56ff-4457-93db-9b9702e3ff43',
#  '4ab46dcc-3395-4e7b-bb87-52e805e12abb': '56898b1b-5aed-4595-ade6-5b73d45a7808',
#  '8559907a-1b27-4673-ae0e-602b83d86deb': 'ba91b97c-6a58-431f-99ae-091ae1a16bc8',
#  'b683d769-9cd7-454a-b546-4e86afe5e3f4': 'e34d9838-8677-405f-b825-5068facac35e',
#  'fe8e4a28-cb6b-4396-adc3-a51f49838d54': '4ccc9a11-4c0b-48a4-848e-edcdd5c8da69',
#  '89b8593e-8436-4dfb-8430-1367d273cbc2': '4b56c2d8-0a77-4566-b8fe-51e66454dd75',
#  '47d95862-b511-4a42-b8b1-961b605f26a3': 'a6ee3a08-02cd-4703-9d6c-3721dad590c8',
#  'a9d67fc5-2e59-4f51-a904-9cac957c9e73': '8573b7f6-c239-4d33-aa19-58f59c7d0499',
#  '43cd6089-f940-463f-bd40-a1f2bf168f67': '3a3f06cf-6324-44c0-9fbe-cbe35289073b',
#  'fedab157-3d87-4f8b-b09b-590c966aa0ba': '38d80e08-5bd4-4e0e-9d11-a60d55148590',
#  '48117328-d486-4f9f-96ab-b0034fe30cd5': '1cd98242-2c09-46dc-8eab-ff593ec4a284',
#  'ecc20fb9-daca-4f65-97ce-f1329696f7ec': 'f4b66637-2c73-4d0b-83ba-3f7e3b3f3c06',
#  'f59733f7-c03c-4712-934e-fb6ea464b604': 'c9f1b338-8d5c-491e-ac9c-cab3df47c1e5',
#  '2a988138-57f5-40bf-851c-3df09f642f05': '96f2819c-ff4b-467a-a599-1d2a0c792f5f',
#  '0d339e3d-c04d-4f61-8cb0-2fd1f18006e9': '6411e428-3416-4aad-a246-f50fe8f3fb4b',
#  '320cdd85-691d-48fb-9eac-d27b2fc5e5f5': '7c4bcab3-4ce3-4a28-92b1-4f8a04c76603',
#  'bf04b495-3291-4508-a497-e6d96dc52362': '22fc6d75-43ef-41aa-993b-b76a84f4c5af',
#  'f5458994-6b3e-4176-9427-7cef2bb6c7d5': '86a7ac96-49f1-4da4-b518-37e4ab31a099',
#  '9aed2e5c-7127-46bd-8331-51407d127d8f': '89639692-ddbf-413e-a0c4-bf75456e2877',
#  '9b9c349b-8f9d-4f0c-829c-fa99e67e90fb': 'b702c675-432e-4034-b542-ef01ad2fd4ff'}

# %% [markdown]
# ### For each re-made uuid, load esaxs data

# %%
saxs_data_fp = '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data'

# %%
import os

# %%
replicate_fps = []
replicate_esaxs_fp = []
replicate_data = {}
for key, val in uuid_mapping.items():
    fps = glob.glob(str(saxs_data_fp + f'/**/subtracted/*{val}*.dat'), recursive = True)
    filenames =  [sn.split('/')[-1] for sn in fps]
    num = [int(fn.split('_')[0]) for fn in filenames]
    #print(num)
    if len(num) > 0:
        esaxs_fp = fps[np.argmin(num)]
        replicate_fps.append(esaxs_fp)
        
        data = io.read_1D_data(esaxs_fp)

        replicate_data[val] = data

# %%
glob.glob(str(saxs_data_fp + f'/**/subtracted/*{val}*.dat'), recursive = True)

# %% [markdown]
# ## For each replicate, find it's pair sample

# %%
original_fps = []
original_data = {}

# %%
for key, val in uuid_mapping.items():
    fps = glob.glob(str(saxs_data_fp + f'/**/subtracted/*{key}*.dat'), recursive = True)
    filenames =  [sn.split('/')[-1] for sn in fps]
    num = [int(fn.split('_')[0]) for fn in filenames]
    #print(num)
    if len(num) > 0:
        esaxs_fp = fps[np.argmin(num)]
        original_fps.append(esaxs_fp)
        
        data = io.read_1D_data(esaxs_fp)

        original_data[key] = data

# %%
target_fp = '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_15_Highlights_replicates/replicate_originals_subtracted'

# %%
for fp in original_fps:
    shutil.copy(fp, target_fp)

# %%
original_fps
# Out:
# ['/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03174_A1-T1_4bec4e18-80bb-44d9-8508-cc464f14b287_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03178_A3-T1_3584700a-8b01-4e59-a53a-1300fd3fac0a_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03184_A6-T1_fed3ab35-04e9-4916-8527-8627191a3bdc_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03186_A7-T1_32ec16b1-c5b5-4d8b-b396-cd1ad4b740d9_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03190_A9-T1_770a433d-0480-4cee-bf12-ce066c24db55_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03200_B2-T1_23850c30-c572-41ad-abf0-7e1bd4fa7397_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_05_StoberRandomCampaignV2/subtracted/03202_B3-T1_4ab46dcc-3395-4e7b-bb87-52e805e12abb_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_07_randomcampaignV3/data/subtracted/03225_D4-T1_8559907a-1b27-4673-ae0e-602b83d86deb_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_07_randomcampaignV3/data/subtracted/03227_D5-T1_b683d769-9cd7-454a-b546-4e86afe5e3f4_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_07_randomcampaignV3/data/subtracted/03237_D10-T1_fe8e4a28-cb6b-4396-adc3-a51f49838d54_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_07_randomcampaignV3/data/subtracted/03239_D11-T1_89b8593e-8436-4dfb-8430-1367d273cbc2_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_07_randomcampaignV3/data/subtracted/03243_E1-T1_47d95862-b511-4a42-b8b1-961b605f26a3_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03293_F2-T2_a9d67fc5-2e59-4f51-a904-9cac957c9e73_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03299_F5-T2_43cd6089-f940-463f-bd40-a1f2bf168f67_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03301_F6-T2_fedab157-3d87-4f8b-b09b-590c966aa0ba_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03303_F7-T2_48117328-d486-4f9f-96ab-b0034fe30cd5_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03309_F10-T2_ecc20fb9-daca-4f65-97ce-f1329696f7ec__000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03311_F11-T2_f59733f7-c03c-4712-934e-fb6ea464b604_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03315_G1-T2_2a988138-57f5-40bf-851c-3df09f642f05_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03317_G2-T2_0d339e3d-c04d-4f61-8cb0-2fd1f18006e9_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03319_G3-T2_320cdd85-691d-48fb-9eac-d27b2fc5e5f5_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03323_G5-T2__bf04b495-3291-4508-a497-e6d96dc52362_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03325_G6-T2_f5458994-6b3e-4176-9427-7cef2bb6c7d5_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03329_G8-T2_9aed2e5c-7127-46bd-8331-51407d127d8f_000_sub.dat',
#  '/mnt/c/Users/bgpel/My Drive/Research/PozzoResearchGroup/Stober_synthesis/SAXS_data/2024_10_11_randomV3_round2/subtracted/03339_H1-T2_9b9c349b-8f9d-4f0c-829c-fa99e67e90fb_000_sub.dat']

# %%
## Plot each pair

# %%
qmin = 0.003
qmax = 0.1

# %%
def chop_data(data, qmin, qmax):
    data = data[data['q'] < qmax]
    data = data[data['q'] > qmin]
    return data

# %%
for key, val in uuid_mapping.items():
    try:
        original = original_data[key][0]
        replicate = replicate_data[val][0]
    except KeyError:
        print(f'Incomplete entry for pair {key}:{val}')
        continue
        
        
    # range select
    original = chop_data(original, qmin, qmax)
    replicate = chop_data(replicate, qmin, qmax)
    
    replicate = manipulate.interpolate_on_q_linear(original, replicate)
    replicate = manipulate.scale_data_integral(original, replicate, qmin, qmax)
    
    fig, ax = plt.subplots(1,1)
    
    ax.loglog(original.q, original.I, ls = 'solid', label = 'original')
    ax.loglog(replicate.q, replicate.I, ls = '--', label = 'replicate')
    
    
    ax.legend()
    ax.set_xlabel('Q [1/A]')
    ax.set_ylabel('I [arb.]')
    
    #ax.set_title(f'Original: {key}')
    
    plt.tight_layout()
    
    plt.savefig(f'replicates_biggerrange/replicate_plot_{key}.png', dpi = 300)
# Out:
# Incomplete entry for pair 4bec4e18-80bb-44d9-8508-cc464f14b287:4fd21940-a331-4524-b730-cf76de1b4d8d
# Incomplete entry for pair 48117328-d486-4f9f-96ab-b0034fe30cd5:1cd98242-2c09-46dc-8eab-ff593ec4a284
# /tmp/ipykernel_119929/149784714.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(1,1)

# %%
saxs_data_processing.manipulate.sc
# Out:
#             q           I       sig
# 9    0.003226  680.557498  8.391142
# 10   0.003566  574.976121  4.268591
# 11   0.003905  466.012067  2.413604
# 12   0.004245  389.592417  1.373186
# 13   0.004584  315.450690  0.853439
# ..        ...         ...       ...
# 142  0.048391    0.015015  0.002173
# 143  0.048730    0.012764  0.002010
# 144  0.049070    0.010288  0.002019
# 145  0.049409    0.010003  0.002115
# 146  0.049749    0.010399  0.001906
#
# [138 rows x 3 columns]

# %%
replicate
# Out:
#             q            I       sig
# 20   0.003133  1248.978790  4.265987
# 21   0.003285  1138.333130  3.931312
# 22   0.003438  1029.833380  3.709791
# 23   0.003591   923.788647  3.450163
# 24   0.003744   820.047356  3.006238
# ..        ...          ...       ...
# 322  0.049282     0.013441  0.005190
# 323  0.049435     0.028277  0.005997
# 324  0.049588     0.016074  0.005612
# 325  0.049740     0.014376  0.005522
# 326  0.049893     0.022200  0.006069
#
# [307 rows x 3 columns]
