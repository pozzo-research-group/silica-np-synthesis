# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import requests

# ----------- Science Jubilee -------------
from science_jubilee import Machine as Jub
from science_jubilee.tools import HTTPSyringe as syringe
from science_jubilee.tools import Pipette
import time
import numpy as np
import pandas as pd
import logging
import sys
sys.path.append('..')
import stober_synthesis_utils as stober

# %%
FORMAT = '%(asctime)s:%(levelname)s:%(name)s:%(message)s'
logging.basicConfig(filename = '2024_10_02_Jubileesynthesiscampaign.log', level = logging.INFO)
logger = logging.getLogger(__name__)

# %%
logger
# Out:
# <Logger __main__ (INFO)>

# %%
jubilee = Jub.Machine(address='192.168.1.2', simulated = False)

# %%
logging.info('test')

# %%
#jubilee.home_all()
#logger.info('Homed Jubilee')

# %%
deck = jubilee.load_deck('lab_automation_deck_AFL_bolton.json')

# %%
sample_table = pd.read_csv('Sample_table_2024_10_02_randomsampleStobercampaign.csv')

# %%
sample_table
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  52bd4d0b-a560-41b9-9916-a20b7043a6b6   240.992906
# 1            1  d365091e-1c27-42db-8aa5-e42d95a7a83d   122.410973
# 2            2  6c56c8e8-e5dd-44a5-9de1-57dd4b1b930a   374.697480
# 3            3  acad2dda-7615-4f85-9e61-3f18a1d016ef   211.244695
# 4            4  a2725e93-e667-4659-baa0-436d07892eff   201.755151
# 5            5  80110593-f1d1-4747-a66c-bd2cb191d257   349.811095
# 6            6  d62f622e-e593-4ecd-9c96-f7d40dee54a9   271.511706
# 7            7  353d5de2-2d81-4ac2-b494-55ceb87dc5b8   222.380016
# 8            8  4bb387b2-b1da-4e7a-a807-4663f27c850d   167.823364
# 9            9  405dfba8-b6f1-47de-8c02-95b9464ed563   303.419822
# 10          10  31a3487a-6e27-458b-a260-2a963d211c69   477.872177
# 11          11  691c77dc-a9ff-4767-a4e3-66ba1269494d   168.427625
# 12          12  1a7098b2-ae30-4c1b-b267-45b30a3537ef   120.666151
# 13          13  6fb83d1a-05dd-4f4f-8ef5-f19f299b4001   340.375353
# 14          14  884b0ae2-ef4a-432f-a6ee-d8acb4ef2cbf   360.223742
# 15          15  c9300f4b-3d17-4ac5-8669-597b2dcc9c2b   190.743657
# 16          16  21c8959f-149c-42ef-9178-af30e5063d27   124.258041
# 17          17  9f0bad93-dc47-450e-9e40-8aa1524308b0   313.837221
# 18          18  a391dc51-13af-43c5-a4bb-d55930c411c2   206.865766
# 19          19  f7018402-c310-4304-874c-66f6fa911e25   147.165825
# 20          20  95383c83-a1e5-4e96-b533-208fb9b50941   419.696074
# 21          21  c660c7cb-0e41-40c7-b8a6-316c2bd9a633   308.408173
# 22          22  d5bb8695-e32f-4bee-8f38-e36e3ff586d0   401.311629
# 23          23  35c87a12-c2b7-4dbd-8d3f-5c6ed8f8d348   137.913447
# 24          24  041717a0-1303-4fb5-9493-5a6fee4a28f2   286.179468
# 25          25  0627746e-8d94-4750-bd11-abad375e25ac   248.814893
# 26          26  ddcee3fe-823c-4ea2-8207-691b36532099   103.544558
# 27          27  cba412d3-978c-4afa-9484-ff1f637248af   192.516162
# 28          28  d79c8e2d-1e53-4b13-8c8f-d2c4cbd8283f   263.455862
# 29          29  5da13d22-3bc7-4538-b3c6-778a2d3754f8   395.849180
# 30          30  99dc73bc-8462-429a-a759-22af08ada179   349.407258
# 31          31  bc9496c8-08af-4e14-901a-ac4a0791d180   116.379548
# 32          32  3d1affd4-b981-4217-96a3-9b978a76742c   193.921376
# 33          33  b26c0daa-c6a8-41a8-be81-8960de81f7db   287.775899
# 34          34  b8d84b76-8b83-4209-82a5-94c5c1ee94ab   133.835355
# 35          35  8e097b30-ca50-46ac-a2cb-e0c6eb4fc210   295.309780
# 36          36  9e9869d4-fd28-4c84-add7-814ce1e4840f   161.169894
# 37          37  22deb5b6-6f79-443a-a258-3d7bea0d42d4   297.098902
# 38          38  55ceeed2-f037-4075-93aa-677e107af9fc   232.937964
# 39          39  ea72f8c3-7f52-4f4c-a7bf-514509d92e69   299.901081
#
#     ammonia_volume  water_volume  ethanol_volume well
# 0        48.361897    336.739998     1173.905199   A1
# 1       142.666568    217.963383     1316.959075   A2
# 2        76.669722    475.623478      873.009321   A3
# 3       102.396664    359.765714     1126.592927   A4
# 4       144.198655    142.034082     1312.012111   A5
# 5        38.105673    269.188955     1142.894277   A6
# 6       110.628143    196.535746     1221.324405   A7
# 7       135.601333    159.708327     1282.310323   A8
# 8       130.215802     37.815428     1464.145406   B1
# 9       109.444388    251.634500     1135.501290   B3
# 10      131.251330    468.706687      722.169806   B4
# 11      114.583146    471.068541     1045.920688   B5
# 12      137.356551    231.538869     1310.438428   B6
# 13       51.098711    209.456193     1199.069743   B8
# 14      105.736396    107.289845     1226.750017   C1
# 15       52.289761     38.508303     1518.458278   C2
# 16       39.907097    281.843927     1353.990934   C3
# 17       58.161053    128.729762     1299.271964   C4
# 18       61.510421    154.913192     1376.710621   C5
# 19       41.728027     55.638305     1555.467843   C6
# 20       68.110501    281.245749     1030.947677   C7
# 21      104.330713    447.144208      940.116907   C8
# 22      133.076732    400.014309      865.597329   D1
# 23       81.962399    478.615095     1101.509059   D2
# 24       93.871231    377.430349     1042.518952   D3
# 25       35.095524     71.453773     1444.635809   D4
# 26      112.663105    423.651716     1160.140622   D5
# 27      141.926793    453.409161     1012.147885   D6
# 28      107.409830    175.398073     1253.736235   D7
# 29       73.371470    324.427677     1006.351673   D8
# 30       89.583991     60.730951     1300.277800   E1
# 31      119.449703    396.655474     1167.515274   E3
# 32      127.985981     39.765051     1438.327592   E4
# 33      127.886370     83.076351     1301.261380   E5
# 34       77.670593    116.732124     1471.761928   E6
# 35       49.639303    439.741414     1015.309503   E8
# 36      110.499931    108.027871     1420.302303   F1
# 37       88.003440    445.960181      968.937477   F2
# 38       59.845684    224.452720     1282.763631   F3
# 39      124.829996    113.941195     1261.327727   F4

# %%
stober.count_stock_vials(sample_table, 15000)
# Out:
# {'teos_count': 1, 'ammonia_count': 1, 'water_count': 1, 'ethanol_count': 4}

# 100.39370280227679 134.42345689767777
# Well D7 form septavialrev1_44_holder_2000ul on slot 2
# 116.40745389543066 134.2806697434554
# Well D8 form septavialrev1_44_holder_2000ul on slot 2
# 132.42120498858452 134.13788258923307
# Well E1 form septavialrev1_44_holder_2000ul on slot 2
# 20.199929782009843 121.11652355838594
# Well E2 form septavialrev1_44_holder_2000ul on slot 2
# 36.21368087516372 120.97373640416359
# Well E3 form septavialrev1_44_holder_2000ul on slot 2
# 52.2274319683176 120.83094924994126
# Well E4 form septavialrev1_44_holder_2000ul on slot 2
# 68.24118306147149 120.68816209571892
# Well E5 form septavialrev1_44_holder_2000ul on slot 2
# 84.25493415462536 120.54537494149659
# Well E6 form septavialrev1_44_holder_2000ul on slot 2
# 100.26868524777926 120.40258778727426
# Well E7 form septavialrev1_44_holder_2000ul on slot 2
# 116.28243634093313 120.25980063305191
# Well E8 form septavialrev1_44_holder_2000ul on slot 2
# 132.296187434087 120.11701347882956
# Well F1 form septavialrev1_44_holder_2000ul on slot 2
# 20.074912227512304 107.09565444798243
# Well F2 form septavialrev1_44_holder_2000ul on slot 2
# 36.08866332066618 106.9528672937601
# Well F3 form septavialrev1_44_holder_2000ul on slot 2
# 52.102414413820064 106.81008013953775
# Well F4 form septavialrev1_44_holder_2000ul on slot 2
# 68.11616550697394 106.66729298531541
# Well F5 form septavialrev1_44_holder_2000ul on slot 2
# 84.12991660012781 106.52450583109308
# Well F6 form septavialrev1_44_holder_2000ul on slot 2
# 100.14366769328171 106.38171867687073
# Well F7 form septavialrev1_44_holder_2000ul on slot 2
# 116.15741878643558 106.2389315226484
# Well F8 form septavialrev1_44_holder_2000ul on slot 2
# 132.17116987958946 106.09614436842607
# New manual offset applied to septavialrev1_44_holder_2000ul

# %%
stocks = jubilee.load_labware('20mlscintillation_12_wellplate_18000ul.json', 4)
stocks.manual_offset([(33.6, 267.0),(118.6, 267.0),(116.6, 210.0)])
# Out:
# Well A1 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 33.6 267.0
# Well A2 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 61.92897670441337 266.50315328462136
# Well A3 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 90.25795340882674 266.0063065692427
# Well A4 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 118.5869301132401 265.50945985386414
# Well B1 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 33.09992310648975 238.48684648972377
# Well B2 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 61.42889981090312 237.98999977434516
# Well B3 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 89.75787651531648 237.49315305896653
# Well B4 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 118.08685321972985 236.9963063435879
# Well C1 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 32.5998462129795 209.97369297944755
# Well C2 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 60.92882291739287 209.47684626406894
# Well C3 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 89.25779962180623 208.9799995486903
# Well C4 form 20mLscintillation 12 Well Plate 18000 µL on slot 4
# 117.58677632621959 208.4831528333117
# New manual offset applied to 20mlscintillation_12_wellplate_18000ul

# %%
tiprack = jubilee.load_labware('opentrons_96_tiprack_300ul.json', 0)
tiprack.manual_offset([(29.7, 77.2), (128.5, 77.4), (129.0, 15.1)])
# Out:
# Well A1 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 29.7 77.2
# Well A2 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 38.681723190738964 77.15486736553363
# Well A3 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 47.66344638147793 77.10973473106728
# Well A4 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 56.6451695722169 77.06460209660091
# Well A5 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 65
 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 56.37683243702153 23.663556520214826
# Well G5 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 65.35855562776048 23.618423885748456
# Well G6 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 74.34027881849946 23.573291251282093
# Well G7 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 83.32200200923842 23.52815861681573
# Well G8 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 92.30372519997738 23.48302598234936
# Well G9 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 101.28544839071635 23.437893347882998
# Well G10 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 110.26717158145533 23.392760713416635
# Well G11 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 119.24889477219429 23.347628078950265
# Well G12 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 128.23061796293328 23.302495444483903
# Well H1 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 29.38694000893873 14.898780160882907
# Well H2 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 38.36866319967769 14.853647526416545
# Well H3 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 47.35038639041666 14.808514891950175
# Well H4 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 56.33210958115563 14.763382257483812
# Well H5 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 65.3138327718946 14.718249623017442
# Well H6 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 74.29555596263357 14.67311698855108
# Well H7 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 83.27727915337253 14.627984354084717
# Well H8 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 92.2590023441115 14.582851719618347
# Well H9 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 101.24072553485047 14.537719085151984
# Well H10 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 110.22244872558944 14.492586450685621
# Well H11 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 119.2041719163284 14.447453816219252
# Well H12 form Opentrons 96 Tip Rack 300 ÂµL on slot 0
# 128.18589510706738 14.402321181752889
# New manual offset applied to opentrons_96_tiprack_300ul

# %%
trash = jubilee.load_labware('agilent_1_reservoir_290ml.json', 1)

# %%
teos_stocks = [stocks[0]]
ammonia_stocks = [stocks[1]]
water_stocks = [stocks[2]]
ethanol_stocks = [stocks[3], stocks[4], stocks[5], stocks[6]]
rinse_stocks = [stocks[7], stocks[8]]

# %% [markdown]
# ## Load Tools

# %%
P300 = Pipette.Pipette.from_config(0, 'Pipette', 'P300_config.json')
jubilee.load_tool(P300)
P300.add_tiprack(tiprack)
P300.trash = trash[0]

# %%
syringe_10 = syringe.HTTPSyringe.from_config(1, "../../science-jubilee/src/science_jubilee/tools/configs/10cc_syringe.json")
syringe_1_1 = syringe.HTTPSyringe.from_config(2, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_1_syringe.json")
syringe_1_2 = syringe.HTTPSyringe.from_config(3, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_2_syringe.json")
syringe_1_3 = syringe.HTTPSyringe.from_config(4, "../../science-jubilee/src/science_jubilee/tools/configs/1cc_3_syringe.json")

# %%
jubilee.load_tool(syringe_10)
jubilee.load_tool(syringe_1_1)
jubilee.load_tool(syringe_1_2)
jubilee.load_tool(syringe_1_3)

# %%
mix_syringe = syringe_10
water_syringe = syringe_1_1
ammonia_syringe = syringe_1_2
teos_syringe = syringe_1_3

# %%
#water_syringe.set_pulsewidth(1350, s = 10)

# %% [markdown]
# ## Load water syringe with water

# %%
#water_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
#water_syringe.set_pulsewidth(water_syringe.empty_position-1, s = 2000)

# %%
#water_syringe.set_pulsewidth(water_syringe.full_position+1, s = 10)

# %%
water_syringe.set_pulsewidth(water_syringe.full_position+150, s = 500)

# %%
water_syringe.load_syringe(750, water_syringe.full_position+150)
# Out:
# Loaded syringe, remaining volume 750 uL

# %% [markdown]
# ## Load ammonia syringe

# %%
#ammonia_syringe.set_pulsewidth(1420, s = 10)

# %%
#ammonia_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
#ammonia_syringe.set_pulsewidth(ammonia_syringe.empty_position-1, s = 2000)

# %%
#ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+1, s = 10)

# %%
ammonia_syringe.set_pulsewidth(ammonia_syringe.full_position+300, s = 500)

# %%
ammonia_syringe.load_syringe(450, ammonia_syringe.full_position+300)
# Out:
# Loaded syringe, remaining volume 450 uL

# %% [markdown]
# ## Load TEOS syringe

# %%
#teos_syringe.load_syringe(600, 1500)
# Out:
# Loaded syringe, remaining volume 600 uL

# %%
#teos_syringe.set_pulsewidth(teos_syringe.empty_position-1, s = 2000)

# %%
#teos_syringe.set_pulsewidth(teos_syringe.full_position+1, s = 100)

# %%
#teos_syringe.set_pulsewidth(teos_syringe.full_position+200, s = 200)

# %%
teos_syringe.load_syringe(690, teos_syringe.full_position+200)
# Out:
# Loaded syringe, remaining volume 690 uL

# %%
mix_syringe.load_syringe(0, 1829)
# Out:
# Loaded syringe, remaining volume 0 uL

# %%
#mix_syringe.set_pulsewidth(1829)

# %% [markdown]
# # Experiment
#
# ### Split into 2 batches

# %% [markdown]
# ## Batch 1

# %%
sample_table_batch1 = sample_table.iloc[0:20]

# %%
location_lookup = {row['uuid']:samples[row['well']] for i, row in sample_table_batch1.iterrows()}

# %%
sample_table_batch1
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 0            0  52bd4d0b-a560-41b9-9916-a20b7043a6b6   240.992906
# 1            1  d365091e-1c27-42db-8aa5-e42d95a7a83d   122.410973
# 2            2  6c56c8e8-e5dd-44a5-9de1-57dd4b1b930a   374.697480
# 3            3  acad2dda-7615-4f85-9e61-3f18a1d016ef   211.244695
# 4            4  a2725e93-e667-4659-baa0-436d07892eff   201.755151
# 5            5  80110593-f1d1-4747-a66c-bd2cb191d257   349.811095
# 6            6  d62f622e-e593-4ecd-9c96-f7d40dee54a9   271.511706
# 7            7  353d5de2-2d81-4ac2-b494-55ceb87dc5b8   222.380016
# 8            8  4bb387b2-b1da-4e7a-a807-4663f27c850d   167.823364
# 9            9  405dfba8-b6f1-47de-8c02-95b9464ed563   303.419822
# 10          10  31a3487a-6e27-458b-a260-2a963d211c69   477.872177
# 11          11  691c77dc-a9ff-4767-a4e3-66ba1269494d   168.427625
# 12          12  1a7098b2-ae30-4c1b-b267-45b30a3537ef   120.666151
# 13          13  6fb83d1a-05dd-4f4f-8ef5-f19f299b4001   340.375353
# 14          14  884b0ae2-ef4a-432f-a6ee-d8acb4ef2cbf   360.223742
# 15          15  c9300f4b-3d17-4ac5-8669-597b2dcc9c2b   190.743657
# 16          16  21c8959f-149c-42ef-9178-af30e5063d27   124.258041
# 17          17  9f0bad93-dc47-450e-9e40-8aa1524308b0   313.837221
# 18          18  a391dc51-13af-43c5-a4bb-d55930c411c2   206.865766
# 19          19  f7018402-c310-4304-874c-66f6fa911e25   147.165825
#
#     ammonia_volume  water_volume  ethanol_volume well
# 0        48.361897    336.739998     1173.905199   A1
# 1       142.666568    217.963383     1316.959075   A2
# 2        76.669722    475.623478      873.009321   A3
# 3       102.396664    359.765714     1126.592927   A4
# 4       144.198655    142.034082     1312.012111   A5
# 5        38.105673    269.188955     1142.894277   A6
# 6       110.628143    196.535746     1221.324405   A7
# 7       135.601333    159.708327     1282.310323   A8
# 8       130.215802     37.815428     1464.145406   B1
# 9       109.444388    251.634500     1135.501290   B3
# 10      131.251330    468.706687      722.169806   B4
# 11      114.583146    471.068541     1045.920688   B5
# 12      137.356551    231.538869     1310.438428   B6
# 13       51.098711    209.456193     1199.069743   B8
# 14      105.736396    107.289845     1226.750017   C1
# 15       52.289761     38.508303     1518.458278   C2
# 16       39.907097    281.843927     1353.990934   C3
# 17       58.161053    128.729762     1299.271964   C4
# 18       61.510421    154.913192     1376.710621   C5
# 19       41.728027     55.638305     1555.467843   C6

# %%
len(location_lookup)
# Out:
# 20

# %%
sample_table_batch1_etohmod = sample_table_batch1.iloc[2:]

# %%
sample_table_batch1_etohmod
# Out:
#     Unnamed: 0                                  uuid  teos_volume  \
# 2            2  6c56c8e8-e5dd-44a5-9de1-57dd4b1b930a   374.697480
# 3            3  acad2dda-7615-4f85-9e61-3f18a1d016ef   211.244695
# 4            4  a2725e93-e667-4659-baa0-436d07892eff   201.755151
# 5            5  80110593-f1d1-4747-a66c-bd2cb191d257   349.811095
# 6            6  d62f622e-e593-4ecd-9c96-f7d40dee54a9   271.511706
# 7            7  353d5de2-2d81-4ac2-b494-55ceb87dc5b8   222.380016
# 8            8  4bb387b2-b1da-4e7a-a807-4663f27c850d   167.823364
# 9            9  405dfba8-b6f1-47de-8c02-95b9464ed563   303.419822
# 10          10  31a3487a-6e27-458b-a260-2a963d211c69   477.872177
# 11          11  691c77dc-a9ff-4767-a4e3-66ba1269494d   168.427625
# 12          12  1a7098b2-ae30-4c1b-b267-45b30a3537ef   120.666151
# 13          13  6fb83d1a-05dd-4f4f-8ef5-f19f299b4001   340.375353
# 14          14  884b0ae2-ef4a-432f-a6ee-d8acb4ef2cbf   360.223742
# 15          15  c9300f4b-3d17-4ac5-8669-597b2dcc9c2b   190.743657
# 16          16  21c8959f-149c-42ef-9178-af30e5063d27   124.258041
# 17          17  9f0bad93-dc47-450e-9e40-8aa1524308b0   313.837221
# 18          18  a391dc51-13af-43c5-a4bb-d55930c411c2   206.865766
# 19          19  f7018402-c310-4304-874c-66f6fa911e25   147.165825
#
#     ammonia_volume  water_volume  ethanol_volume well
# 2        76.669722    475.623478      873.009321   A3
# 3       102.396664    359.765714     1126.592927   A4
# 4       144.198655    142.034082     1312.012111   A5
# 5        38.105673    269.188955     1142.894277   A6
# 6       110.628143    196.535746     1221.324405   A7
# 7       135.601333    159.708327     1282.310323   A8
# 8       130.215802     37.815428     1464.145406   B1
# 9       109.444388    251.634500     1135.501290   B3
# 10      131.251330    468.706687      722.169806   B4
# 11      114.583146    471.068541     1045.920688   B5
# 12      137.356551    231.538869     1310.438428   B6
# 13       51.098711    209.456193     1199.069743   B8
# 14      105.736396    107.289845     1226.750017   C1
# 15       52.289761     38.508303     1518.458278   C2
# 16       39.907097    281.843927     1353.990934   C3
# 17       58.161053    128.729762     1299.271964   C4
# 18       61.510421    154.913192     1376.710621   C5
# 19       41.728027     55.638305     1555.467843   C6

# %%
ethanol_stocks[2:]
# Out:
# [Well B2 form 20mLscintillation 12 Well Plate 18000 µL on slot 4,
#  Well B3 form 20mLscintillation 12 Well Plate 18000 µL on slot 4]

# %% [markdown]
# ## Pipette ethanol

# %%
stober.add_etoh(jubilee, P300, sample_table_batch1_etohmod, location_lookup, ethanol_stocks[2:], 290, 15000)

# %% [markdown]
# ## Dispense water

# %%
stober.add_reactants_batch(jubilee, water_syringe, mix_syringe, sample_table_batch1, location_lookup, 'water_volume', water_stocks)

# %% [markdown]
# ## dispense Ammonia

# %%
stober.add_reactants_batch(jubilee, ammonia_syringe, mix_syringe, sample_table_batch1, location_lookup, 'ammonia_volume', ammonia_stocks)

# %% [markdown]
# ## mix precursors

# %%
len(location_lookup)
# Out:
# 20

# %%
stober.first_mix(jubilee, mix_syringe, 2000, location_lookup, rinse_stocks, 5)

# %% [markdown]
# ## Add TEOS and mix

# %%
stober.add_reactants_batch(jubilee, teos_syringe, mix_syringe, sample_table_batch1, location_lookup, 'teos_volume', teos_stocks, mix_after=(2000, 5, rinse_stocks))

# %%
jubilee.park_tool()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 jubilee.park_tool()
#
# File ~/Code/science-jubilee/src/science_jubilee/Machine.py:90, in requires_safe_z.<locals>.z_check(self, *args, **kwds)
#      88 if current_z < safe_z:
#      89     self.move_to(z=safe_z + 20)
# ---> 90 return func(self, *args, **kwds)
#
# File ~/Code/science-jubilee/src/science_jubilee/Machine.py:990, in Machine.park_tool(self)
#     988 # Update the cached value to prevent read delays.
#     989 current_tool_index = self.active_tool_index
# --> 990 self.tools[current_tool_index]["tool"].is_active_tool = False
#     991 self._active_tool_index = -1
#
# KeyError: -1

# %% [markdown]
# ## Batch 2

# %%
sample_table_batch2 = sample_table[20:]
location_lookup = {row['uuid']:samples[row['well']] for i, row in sample_table_batch2.iterrows()}

# %%
jubilee.park_tool()

# %%
stober.add_etoh(jubilee, P300, sample_table_batch2, location_lookup, ethanol_stocks[2:], 290, 15000)

# %%
stober.add_reactants_batch(jubilee, water_syringe, mix_syringe, sample_table_batch2, location_lookup, 'water_volume', water_stocks)

# %%
stober.add_reactants_batch(jubilee, ammonia_syringe, mix_syringe, sample_table_batch2, location_lookup, 'ammonia_volume', ammonia_stocks)

# %%
stober.first_mix(jubilee, mix_syringe, 2000, location_lookup, rinse_stocks, 5)

# %%
stober.add_reactants_batch(jubilee, teos_syringe, mix_syringe, sample_table_batch2, location_lookup, 'teos_volume', teos_stocks, mix_after=(2000, 5, rinse_stocks))
