# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append('../sample_utilities/')
import samples
import matplotlib.pyplot as plt

# %%
target_volume = 1800

# %%
samples_gen = []
for i in range(40):
    sample = samples.SolidSilicaSample(target_volume, reactant_fp='../sample_utilities/constants.json')
    sample.generate_random_vol_fractions()
    sample.calculate_reactant_volumes()
    samples_gen.append(sample)

# %%
synth_table = samples.generate_synthesis_table(samples_gen)

# %%
rows = ['A', 'B', 'C', 'D', 'E', 'F']
cols = [1, 2, 3, 4, 5, 6, 7, 8]

wells = []
for row in rows:
    for col in cols:
        if row in ['B', 'E'] and col in [2, 7]:
            pass
        else:
            wells.append(row + str(col))

# %%
synth_table['well'] = wells[0:len(synth_table)]

# %%
synth_table
# Out:
#                                     uuid  teos_volume  ammonia_volume  \
# 0   52bd4d0b-a560-41b9-9916-a20b7043a6b6   240.992906       48.361897
# 1   d365091e-1c27-42db-8aa5-e42d95a7a83d   122.410973      142.666568
# 2   6c56c8e8-e5dd-44a5-9de1-57dd4b1b930a   374.697480       76.669722
# 3   acad2dda-7615-4f85-9e61-3f18a1d016ef   211.244695      102.396664
# 4   a2725e93-e667-4659-baa0-436d07892eff   201.755151      144.198655
# 5   80110593-f1d1-4747-a66c-bd2cb191d257   349.811095       38.105673
# 6   d62f622e-e593-4ecd-9c96-f7d40dee54a9   271.511706      110.628143
# 7   353d5de2-2d81-4ac2-b494-55ceb87dc5b8   222.380016      135.601333
# 8   4bb387b2-b1da-4e7a-a807-4663f27c850d   167.823364      130.215802
# 9   405dfba8-b6f1-47de-8c02-95b9464ed563   303.419822      109.444388
# 10  31a3487a-6e27-458b-a260-2a963d211c69   477.872177      131.251330
# 11  691c77dc-a9ff-4767-a4e3-66ba1269494d   168.427625      114.583146
# 12  1a7098b2-ae30-4c1b-b267-45b30a3537ef   120.666151      137.356551
# 13  6fb83d1a-05dd-4f4f-8ef5-f19f299b4001   340.375353       51.098711
# 14  884b0ae2-ef4a-432f-a6ee-d8acb4ef2cbf   360.223742      105.736396
# 15  c9300f4b-3d17-4ac5-8669-597b2dcc9c2b   190.743657       52.289761
# 16  21c8959f-149c-42ef-9178-af30e5063d27   124.258041       39.907097
# 17  9f0bad93-dc47-450e-9e40-8aa1524308b0   313.837221       58.161053
# 18  a391dc51-13af-43c5-a4bb-d55930c411c2   206.865766       61.510421
# 19  f7018402-c310-4304-874c-66f6fa911e25   147.165825       41.728027
# 20  95383c83-a1e5-4e96-b533-208fb9b50941   419.696074       68.110501
# 21  c660c7cb-0e41-40c7-b8a6-316c2bd9a633   308.408173      104.330713
# 22  d5bb8695-e32f-4bee-8f38-e36e3ff586d0   401.311629      133.076732
# 23  35c87a12-c2b7-4dbd-8d3f-5c6ed8f8d348   137.913447       81.962399
# 24  041717a0-1303-4fb5-9493-5a6fee4a28f2   286.179468       93.871231
# 25  0627746e-8d94-4750-bd11-abad375e25ac   248.814893       35.095524
# 26  ddcee3fe-823c-4ea2-8207-691b36532099   103.544558      112.663105
# 27  cba412d3-978c-4afa-9484-ff1f637248af   192.516162      141.926793
# 28  d79c8e2d-1e53-4b13-8c8f-d2c4cbd8283f   263.455862      107.409830
# 29  5da13d22-3bc7-4538-b3c6-778a2d3754f8   395.849180       73.371470
# 30  99dc73bc-8462-429a-a759-22af08ada179   349.407258       89.583991
# 31  bc9496c8-08af-4e14-901a-ac4a0791d180   116.379548      119.449703
# 32  3d1affd4-b981-4217-96a3-9b978a76742c   193.921376      127.985981
# 33  b26c0daa-c6a8-41a8-be81-8960de81f7db   287.775899      127.886370
# 34  b8d84b76-8b83-4209-82a5-94c5c1ee94ab   133.835355       77.670593
# 35  8e097b30-ca50-46ac-a2cb-e0c6eb4fc210   295.309780       49.639303
# 36  9e9869d4-fd28-4c84-add7-814ce1e4840f   161.169894      110.499931
# 37  22deb5b6-6f79-443a-a258-3d7bea0d42d4   297.098902       88.003440
# 38  55ceeed2-f037-4075-93aa-677e107af9fc   232.937964       59.845684
# 39  ea72f8c3-7f52-4f4c-a7bf-514509d92e69   299.901081      124.829996
#
#     water_volume  ethanol_volume well
# 0     336.739998     1173.905199   A1
# 1     217.963383     1316.959075   A2
# 2     475.623478      873.009321   A3
# 3     359.765714     1126.592927   A4
# 4     142.034082     1312.012111   A5
# 5     269.188955     1142.894277   A6
# 6     196.535746     1221.324405   A7
# 7     159.708327     1282.310323   A8
# 8      37.815428     1464.145406   B1
# 9     251.634500     1135.501290   B3
# 10    468.706687      722.169806   B4
# 11    471.068541     1045.920688   B5
# 12    231.538869     1310.438428   B6
# 13    209.456193     1199.069743   B8
# 14    107.289845     1226.750017   C1
# 15     38.508303     1518.458278   C2
# 16    281.843927     1353.990934   C3
# 17    128.729762     1299.271964   C4
# 18    154.913192     1376.710621   C5
# 19     55.638305     1555.467843   C6
# 20    281.245749     1030.947677   C7
# 21    447.144208      940.116907   C8
# 22    400.014309      865.597329   D1
# 23    478.615095     1101.509059   D2
# 24    377.430349     1042.518952   D3
# 25     71.453773     1444.635809   D4
# 26    423.651716     1160.140622   D5
# 27    453.409161     1012.147885   D6
# 28    175.398073     1253.736235   D7
# 29    324.427677     1006.351673   D8
# 30     60.730951     1300.277800   E1
# 31    396.655474     1167.515274   E3
# 32     39.765051     1438.327592   E4
# 33     83.076351     1301.261380   E5
# 34    116.732124     1471.761928   E6
# 35    439.741414     1015.309503   E8
# 36    108.027871     1420.302303   F1
# 37    445.960181      968.937477   F2
# 38    224.452720     1282.763631   F3
# 39    113.941195     1261.327727   F4

# %%
fig, ax = plt.subplots(2,2)

ax[0,0].scatter(synth_table['teos_volume'], synth_table['ammonia_volume'])
ax[0,1].scatter(synth_table['teos_volume'], synth_table['water_volume'])
ax[1,0].scatter(synth_table['teos_volume'], synth_table['ethanol_volume'])
ax[1,1].scatter(synth_table['ammonia_volume'], synth_table['water_volume'])

# %%
synth_table.ammonia_volume.hist()
# Out:
# <Axes: >

# %%
synth_table.water_volume.hist()
# Out:
# <Axes: >
